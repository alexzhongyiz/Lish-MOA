# %%
# import python packages
import os
import sys
import copy
import time
import datetime
import warnings
warnings.filterwarnings('ignore')

import random
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import torch

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# set parameters
num_fold = 5
seed = 42
model_seeds = [42]
model_seeds = [1234, 5678, 3721, 2020, 1110]

num_quantile = 100
threshold_var = 0.8
pca_gene = 600
pca_cell = 50
cluster_gene = 35
cluster_cell = 5

kaggle_id = 'MOA'
user_id = 'smartzdp'
model_id = 'pytorch-7head'
target_id = 'multilabel'
timestamp_id = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")

unique_model_id = f"{kaggle_id}-{user_id}-{model_id}-{target_id}-{timestamp_id}"

path_input = '../input/lish-moa'
path_output = f'./{unique_model_id}'
os.mkdir(path_output)

print(f'unique model id: {unique_model_id}')
# Out:
# unique model id: MOA-smartzdp-pytorch-4head-multilabel-20201110143332325906

# %%
# random seed
def seed_everything(seed=2020):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
seed_everything(seed=seed)

# %%
# load datasets
df_names = ['train_drug', 'train_features', 'train_targets_scored', 'train_targets_nonscored', 'test_features', 'sample_submission']
df = {}
for name in df_names:
    df[name] = pd.read_csv(f"{path_input}/{name}.csv", index_col=0)
    print(f"{name}: {df[name].shape}")
# Out:
# train_drug: (23814, 1)
# train_features: (23814, 875)
# train_targets_scored: (23814, 206)
# train_targets_nonscored: (23814, 402)
# test_features: (3982, 875)
# sample_submission: (3982, 206)

# %%
# Drug and MultiLabel Stratification Code
# https://www.kaggle.com/ppicheta/lish-moa-drug-aware-multilabelstratifiedkfold
from sklearn.model_selection._split import _BaseKFold

import sys
sys.path.append('../input/iterative-stratification/iterative-stratification-master/')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

class DrugAwareMultilabelStratifiedKFold(_BaseKFold):
    SAMPLES_PER_EXPERIMENT = 6
    
    def __init__(self,
                 max_experiment_cnt=3,
                 n_splits=3,
                 shuffle=False,
                 random_state=None):
        super().__init__(n_splits=n_splits, 
                         shuffle=shuffle, 
                         random_state=random_state)
        self._skf = MultilabelStratifiedKFold(n_splits=n_splits, 
                                              shuffle=shuffle, 
                                              random_state=random_state)
        self.drug_threshold = self.SAMPLES_PER_EXPERIMENT * max_experiment_cnt
    
    def _iter_test_indices(self, X=None, y=None, groups=None):
        drug_set = X.merge(y, left_index=True, right_index=True)
        targets = y.columns
        vc = X['drug_id'].value_counts()
        vc1 = vc.loc[vc <= self.drug_threshold].index.sort_values()
        vc2 = vc.loc[vc > self.drug_threshold].index.sort_values()
        
        drug_id_to_fold = {}
        sig_id_to_fold = {}
        if len(vc1) > 0:
            tmp = drug_set.groupby('drug_id')[targets].mean().loc[vc1]
            for fold, (_, idx_val) in enumerate(self._skf.split(tmp, tmp[targets])):
                drug_id_to_fold.update({k: fold for k in tmp.index[idx_val].values})
        
        if len(vc2) > 0:
            tmp = drug_set.loc[drug_set.drug_id.isin(vc2)].reset_index()
            for fold, (_, idx_val) in enumerate(self._skf.split(tmp, tmp[targets])):
                sig_id_to_fold.update({k: fold for k in tmp.sig_id[idx_val].values})
        
        drug_set['fold'] = drug_set.drug_id.map(drug_id_to_fold)
        unset_folds = drug_set.fold.isna()
        drug_set.loc[unset_folds, 'fold'] = drug_set.loc[unset_folds].index.map(sig_id_to_fold)
        test_folds = drug_set.fold.astype('int8').values
        
        for i in range(self.n_splits):
            yield test_folds == i

# %%
# assign k-fold
df['train_targets'] = pd.concat([df['train_targets_scored'], df['train_targets_nonscored']], axis=1)
df['train_drug'].loc[:, 'kfold'] = -1

kf = DrugAwareMultilabelStratifiedKFold(n_splits=num_fold, shuffle=True, random_state=seed)
for fold, (_, val) in enumerate(kf.split(X=df['train_drug'], y=df['train_targets'])):
    df['train_drug'].loc[df['train_drug'].index[val], 'kfold'] = fold

print('unique drug_id:')
df['train_drug'].groupby(['kfold'])['drug_id'].nunique()
# Out:
# unique drug_id:
# kfold
# 0    666
# 1    666
# 2    666
# 3    666
# 4    665
# Name: drug_id, dtype: int64

# %%
# split the features
df['train_cp'] = df['train_features'].filter(regex='^cp_')
df['train_gene_cell'] = df['train_features'].filter(regex='^(g|c)-')
df['test_cp'] = df['test_features'].filter(regex='^cp_')
df['test_gene_cell'] = df['test_features'].filter(regex='^(g|c)-')

# %%
# Gauss Rank Transformation
from sklearn.preprocessing import QuantileTransformer

df['train_gene_cell_qt'] = pd.DataFrame(columns=df['train_gene_cell'].columns, index=df['train_gene_cell'].index)
df['test_gene_cell_qt'] = pd.DataFrame(columns=df['test_gene_cell'].columns, index=df['test_gene_cell'].index)

qt = QuantileTransformer(n_quantiles=num_quantile, random_state=seed, output_distribution='normal')

df['train_gene_cell_qt'].iloc[:, :] = qt.fit_transform(df['train_gene_cell'])
df['test_gene_cell_qt'].iloc[:, :] = qt.transform(df['test_gene_cell'])

# %%
# pca features
from sklearn.decomposition import PCA

def generate_pca_feature(df_train, df_test, prefix, num_pca, seed):
    X_pca = PCA(n_components=num_pca, random_state=seed).fit_transform(pd.concat([df_train, df_test]))
    
    col_pca = [f'pca-{prefix}-{i}' for i in range(num_pca)]
    df_train_pca = pd.DataFrame(X_pca[:df_train.shape[0], :], columns=col_pca, index=df_train.index)
    df_test_pca = pd.DataFrame(X_pca[-df_test.shape[0]:, :], columns=col_pca, index=df_test.index)
    
    return df_train_pca, df_test_pca

df['train_gene'] = df['train_gene_cell_qt'].filter(regex='^g-')
df['train_cell'] = df['train_gene_cell_qt'].filter(regex='^c-')
df['test_gene'] = df['test_gene_cell_qt'].filter(regex='^g-')
df['test_cell'] = df['test_gene_cell_qt'].filter(regex='^c-')

df['train_gene_pca'], df['test_gene_pca'] = generate_pca_feature(df['train_gene'], df['test_gene'], 'g', pca_gene, seed)
df['train_cell_pca'], df['test_cell_pca'] = generate_pca_feature(df['train_cell'], df['test_cell'], 'c', pca_cell, seed)

# %%
# feature selection
from sklearn.feature_selection import VarianceThreshold

def select_features(df_train, df_test, threshold_var):
    selector = VarianceThreshold(threshold=threshold_var)
    selector.fit(pd.concat([df_train, df_test], axis=0))
    
    return df_train.columns[selector.get_support()].to_list()

gene_cols = select_features(df['train_gene'], df['test_gene'], threshold_var)
cell_cols = select_features(df['train_cell'], df['test_cell'], threshold_var)
gene_pca_cols = select_features(df['train_gene_pca'], df['test_gene_pca'], threshold_var)
cell_pca_cols = select_features(df['train_cell_pca'], df['test_cell_pca'], threshold_var)

print(f'gene features: {len(gene_cols)}')
print(f'cell features: {len(cell_cols)}')
print(f'gene pca features: {len(gene_pca_cols)}')
print(f'cell pca features: {len(cell_pca_cols)}')
# Out:
# gene features: 772
# cell features: 100
# gene pca features: 156
# cell pca features: 8

# %%
# cluster features
from sklearn.cluster import KMeans

def generate_cluster_feature(df_train, df_test, prefix, num_cluster, seed):
    y_cluster = KMeans(n_clusters=num_cluster, random_state=seed).fit(pd.concat([df_train, df_test], axis=0)).labels_
    X_cluster = pd.get_dummies(y_cluster).values
    
    col_cluster = [f'cluster-{prefix}-{i}' for i in range(num_cluster)]
    df_train_cluster = pd.DataFrame(X_cluster[:df_train.shape[0], :], columns=col_cluster, index=df_train.index)
    df_test_cluster = pd.DataFrame(X_cluster[-df_test.shape[0]:, :], columns=col_cluster, index=df_test.index)
    
    return df_train_cluster, df_test_cluster

df['train_gene_cluster'], df['test_gene_cluster'] = generate_cluster_feature(df['train_gene'], df['test_gene'], 'g', cluster_gene, seed)
df['train_cell_cluster'], df['test_cell_cluster'] = generate_cluster_feature(df['train_cell'], df['test_cell'], 'c', cluster_cell, seed)

gene_cluster_cols = df['train_gene_cluster'].columns.to_list()
cell_cluster_cols = df['train_cell_cluster'].columns.to_list()

print(f'gene cluster features: {len(gene_cluster_cols)}')
print(f'cell cluster features: {len(cell_cluster_cols)}')
# Out:
# gene cluster features: 35
# cell cluster features: 5

# %%
# statistics features

def generate_statistics_feature(df_raw, prefix):
    df_stats = pd.DataFrame({f'stats-{prefix}-sum': df_raw.sum(axis=1), 
                             f'stats-{prefix}-mean': df_raw.mean(axis=1), 
                             f'stats-{prefix}-std': df_raw.std(axis=1), 
                             f'stats-{prefix}-kurtosis': df_raw.kurtosis(axis=1), 
                             f'stats-{prefix}-skew': df_raw.skew(axis=1)})
    
    return df_stats

df['train_stats'] = pd.concat([generate_statistics_feature(df['train_gene'], 'g'), 
                               generate_statistics_feature(df['train_cell'], 'c'), 
                               generate_statistics_feature(df['train_gene_cell_qt'], 'gc')], axis=1)
df['test_stats'] = pd.concat([generate_statistics_feature(df['test_gene'], 'g'), 
                              generate_statistics_feature(df['test_cell'], 'c'), 
                              generate_statistics_feature(df['test_gene_cell_qt'], 'gc')], axis=1)

stats_cols = df['train_stats'].columns.to_list()

print(f'statistics features: {len(stats_cols)}')
# Out:
# statistics features: 15

# %%
# process cp features
df['train_cpoh'] = pd.get_dummies(df['train_cp'][['cp_time', 'cp_dose']], columns=['cp_time', 'cp_dose'])
df['test_cpoh'] = pd.get_dummies(df['test_cp'][['cp_time', 'cp_dose']], columns=['cp_time', 'cp_dose'])

cpoh_cols = df['train_cpoh'].columns.to_list()
print(f'cpoh features: {len(cpoh_cols)}')
# Out:
# cpoh features: 5

# %%
# concatenate the train set
feature_cols = cpoh_cols + gene_cols + cell_cols + gene_pca_cols + cell_pca_cols + gene_cluster_cols + cell_cluster_cols + stats_cols
target_cols = df['train_targets_scored'].columns.to_list()

df['train_concat'] = pd.concat([df['train_drug']['kfold'], df['train_targets_scored'], df['train_cpoh'], 
                                df['train_gene'][gene_cols], df['train_cell'][cell_cols], 
                                df['train_gene_pca'][gene_pca_cols], df['train_cell_pca'][cell_pca_cols], 
                                df['train_gene_cluster'], df['train_cell_cluster'], df['train_stats']], axis=1)

df['test_concat'] = pd.concat([df['test_cpoh'], 
                               df['test_gene'][gene_cols], df['test_cell'][cell_cols], 
                               df['test_gene_pca'][gene_pca_cols], df['test_cell_pca'][cell_pca_cols], 
                               df['test_gene_cluster'], df['test_cell_cluster'], df['test_stats']], axis=1)

# drop ctl_vehicle
df['train_concat'] = df['train_concat'].loc[df['train_cp']['cp_type'] == 'trt_cp']
df['test_concat'] = df['test_concat'].loc[df['test_cp']['cp_type'] == 'trt_cp']

# %%
# rename dataset
train = df['train_concat']
test = df['test_concat']

print(f"train shape: {train.shape}")
print(f"test shape: {test.shape}")

print(f"train kfold counts: \n{train['kfold'].value_counts(sort=False)}")
# Out:
# train shape: (21948, 1303)
# test shape: (3624, 1096)
# train kfold counts:
# 0    4394
# 1    4424
# 2    4360
# 3    4395
# 4    4375
# Name: kfold, dtype: int64

# %%
# 7-head pytorch model
import torch.nn as nn

class Model(nn.Module):
    def __init__(self, num_gene_features, num_cell_features, num_gene_pca_features, num_cell_pca_features, 
                 num_gene_cluster_features, num_cell_cluster_features, num_stats_features, num_targets, 
                 gene_hidden_size, cell_hidden_size, gene_pca_hidden_size, cell_pca_hidden_size, 
                 gene_cluster_hidden_size, cell_cluster_hidden_size, stats_hidden_size):
        super(Model, self).__init__()
        self.gene_batch_norm1 = nn.BatchNorm1d(num_gene_features)
        self.gene_dropout1 = nn.Dropout(0.20)
        self.gene_dense1 = nn.utils.weight_norm(nn.Linear(num_gene_features, gene_hidden_size))
        self.gene_batch_norm2 = nn.BatchNorm1d(gene_hidden_size)
        self.gene_dropout2 = nn.Dropout(0.30)
        self.gene_dense2 = nn.utils.weight_norm(nn.Linear(gene_hidden_size, gene_hidden_size))
        
        self.cell_batch_norm1 = nn.BatchNorm1d(num_cell_features)
        self.cell_dropout1 = nn.Dropout(0.20)
        self.cell_dense1 = nn.utils.weight_norm(nn.Linear(num_cell_features, cell_hidden_size))
        self.cell_batch_norm2 = nn.BatchNorm1d(cell_hidden_size)
        self.cell_dropout2 = nn.Dropout(0.30)
        self.cell_dense2 = nn.utils.weight_norm(nn.Linear(cell_hidden_size, cell_hidden_size))
        
        self.gene_pca_batch_norm1 = nn.BatchNorm1d(num_gene_pca_features)
        self.gene_pca_dropout1 = nn.Dropout(0.20)
        self.gene_pca_dense1 = nn.utils.weight_norm(nn.Linear(num_gene_pca_features, gene_pca_hidden_size))
        self.gene_pca_batch_norm2 = nn.BatchNorm1d(gene_pca_hidden_size)
        self.gene_pca_dropout2 = nn.Dropout(0.30)
        self.gene_pca_dense2 = nn.utils.weight_norm(nn.Linear(gene_pca_hidden_size, gene_pca_hidden_size))
        
        self.cell_pca_batch_norm1 = nn.BatchNorm1d(num_cell_pca_features)
        self.cell_pca_dropout1 = nn.Dropout(0.20)
        self.cell_pca_dense1 = nn.utils.weight_norm(nn.Linear(num_cell_pca_features, cell_pca_hidden_size))
        self.cell_pca_batch_norm2 = nn.BatchNorm1d(cell_pca_hidden_size)
        self.cell_pca_dropout2 = nn.Dropout(0.30)
        self.cell_pca_dense2 = nn.utils.weight_norm(nn.Linear(cell_pca_hidden_size, cell_pca_hidden_size))
        
        self.gene_cluster_batch_norm1 = nn.BatchNorm1d(num_gene_cluster_features)
        self.gene_cluster_dropout1 = nn.Dropout(0.20)
        self.gene_cluster_dense1 = nn.utils.weight_norm(nn.Linear(num_gene_cluster_features, gene_cluster_hidden_size))
        self.gene_cluster_batch_norm2 = nn.BatchNorm1d(gene_cluster_hidden_size)
        self.gene_cluster_dropout2 = nn.Dropout(0.30)
        self.gene_cluster_dense2 = nn.utils.weight_norm(nn.Linear(gene_cluster_hidden_size, gene_cluster_hidden_size))
        
        self.cell_cluster_batch_norm1 = nn.BatchNorm1d(num_cell_cluster_features)
        self.cell_cluster_dropout1 = nn.Dropout(0.20)
        self.cell_cluster_dense1 = nn.utils.weight_norm(nn.Linear(num_cell_cluster_features, cell_cluster_hidden_size))
        self.cell_cluster_batch_norm2 = nn.BatchNorm1d(cell_cluster_hidden_size)
        self.cell_cluster_dropout2 = nn.Dropout(0.30)
        self.cell_cluster_dense2 = nn.utils.weight_norm(nn.Linear(cell_cluster_hidden_size, cell_cluster_hidden_size))
        
        self.stats_batch_norm1 = nn.BatchNorm1d(num_stats_features)
        self.stats_dropout1 = nn.Dropout(0.20)
        self.stats_dense1 = nn.utils.weight_norm(nn.Linear(num_stats_features, stats_hidden_size))
        self.stats_batch_norm2 = nn.BatchNorm1d(stats_hidden_size)
        self.stats_dropout2 = nn.Dropout(0.30)
        self.stats_dense2 = nn.utils.weight_norm(nn.Linear(stats_hidden_size, stats_hidden_size))
        
        self.batch_norm3 = nn.BatchNorm1d(gene_hidden_size + cell_hidden_size + gene_pca_hidden_size + cell_pca_hidden_size + \
                                          gene_cluster_hidden_size + cell_cluster_hidden_size + stats_hidden_size)
        self.dropout3 = nn.Dropout(0.25)
        self.dense3 = nn.utils.weight_norm(nn.Linear(gene_hidden_size + cell_hidden_size + gene_pca_hidden_size + cell_pca_hidden_size + \
                                                     gene_cluster_hidden_size + cell_cluster_hidden_size + stats_hidden_size, num_targets))
    
    def forward(self, gene_x, cell_x, gene_pca_x, cell_pca_x, gene_cluster_x, cell_cluster_x, stats_x):
        gene_x = self.gene_batch_norm1(gene_x)
        gene_x = self.gene_dropout1(gene_x)
        gene_x = nn.functional.relu(self.gene_dense1(gene_x))
        gene_x = self.gene_batch_norm2(gene_x)
        gene_x = self.gene_dropout2(gene_x)
        gene_x = nn.functional.relu(self.gene_dense2(gene_x))
        
        cell_x = self.cell_batch_norm1(cell_x)
        cell_x = self.cell_dropout1(cell_x)
        cell_x = nn.functional.relu(self.cell_dense1(cell_x))
        cell_x = self.cell_batch_norm2(cell_x)
        cell_x = self.cell_dropout2(cell_x)
        cell_x = nn.functional.relu(self.cell_dense2(cell_x))
        
        gene_pca_x = self.gene_pca_batch_norm1(gene_pca_x)
        gene_pca_x = self.gene_pca_dropout1(gene_pca_x)
        gene_pca_x = nn.functional.relu(self.gene_pca_dense1(gene_pca_x))
        gene_pca_x = self.gene_pca_batch_norm2(gene_pca_x)
        gene_pca_x = self.gene_pca_dropout2(gene_pca_x)
        gene_pca_x = nn.functional.relu(self.gene_pca_dense2(gene_pca_x))
        
        cell_pca_x = self.cell_pca_batch_norm1(cell_pca_x)
        cell_pca_x = self.cell_pca_dropout1(cell_pca_x)
        cell_pca_x = nn.functional.relu(self.cell_pca_dense1(cell_pca_x))
        cell_pca_x = self.cell_pca_batch_norm2(cell_pca_x)
        cell_pca_x = self.cell_pca_dropout2(cell_pca_x)
        cell_pca_x = nn.functional.relu(self.cell_pca_dense2(cell_pca_x))
        
        gene_cluster_x = self.gene_cluster_batch_norm1(gene_cluster_x)
        gene_cluster_x = self.gene_cluster_dropout1(gene_cluster_x)
        gene_cluster_x = nn.functional.relu(self.gene_cluster_dense1(gene_cluster_x))
        gene_cluster_x = self.gene_cluster_batch_norm2(gene_cluster_x)
        gene_cluster_x = self.gene_cluster_dropout2(gene_cluster_x)
        gene_cluster_x = nn.functional.relu(self.gene_cluster_dense2(gene_cluster_x))
        
        cell_cluster_x = self.cell_cluster_batch_norm1(cell_cluster_x)
        cell_cluster_x = self.cell_cluster_dropout1(cell_cluster_x)
        cell_cluster_x = nn.functional.relu(self.cell_cluster_dense1(cell_cluster_x))
        cell_cluster_x = self.cell_cluster_batch_norm2(cell_cluster_x)
        cell_cluster_x = self.cell_cluster_dropout2(cell_cluster_x)
        cell_cluster_x = nn.functional.relu(self.cell_cluster_dense2(cell_cluster_x))
        
        stats_x = self.stats_batch_norm1(stats_x)
        stats_x = self.stats_dropout1(stats_x)
        stats_x = nn.functional.relu(self.stats_dense1(stats_x))
        stats_x = self.stats_batch_norm2(stats_x)
        stats_x = self.stats_dropout2(stats_x)
        stats_x = nn.functional.relu(self.stats_dense2(stats_x))
                
        x = torch.cat((gene_x, cell_x, gene_pca_x, cell_pca_x, gene_cluster_x, cell_cluster_x, stats_x), dim=1)
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = self.dense3(x)
        
        return x

# %%
# 7-head pytorch dataset
class TrainDataSet:
    def __init__(self, gene_features, cell_features, gene_pca_features, cell_pca_features, 
                 gene_cluster_features, cell_cluster_features, stats_features, targets):
        self.gene_features = gene_features
        self.cell_features = cell_features
        self.gene_pca_features = gene_pca_features
        self.cell_pca_features = cell_pca_features
        self.gene_cluster_features = gene_cluster_features
        self.cell_cluster_features = cell_cluster_features
        self.stats_features = stats_features
        self.targets = targets
    
    def __len__(self):
        return (self.gene_features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'gene_x' : torch.tensor(self.gene_features[idx, :], dtype=torch.float), 
            'cell_x' : torch.tensor(self.cell_features[idx, :], dtype=torch.float), 
            'gene_pca_x' : torch.tensor(self.gene_pca_features[idx, :], dtype=torch.float), 
            'cell_pca_x' : torch.tensor(self.cell_pca_features[idx, :], dtype=torch.float), 
            'gene_cluster_x' : torch.tensor(self.gene_cluster_features[idx, :], dtype=torch.float), 
            'cell_cluster_x' : torch.tensor(self.cell_cluster_features[idx, :], dtype=torch.float), 
            'stats_x' : torch.tensor(self.stats_features[idx, :], dtype=torch.float), 
            'y' : torch.tensor(self.targets[idx, :], dtype=torch.float)
        }
        
        return dct

class TestDataSet:
    def __init__(self, gene_features, cell_features, gene_pca_features, cell_pca_features, 
                 gene_cluster_features, cell_cluster_features, stats_features):
        self.gene_features = gene_features
        self.cell_features = cell_features
        self.gene_pca_features = gene_pca_features
        self.cell_pca_features = cell_pca_features
        self.gene_cluster_features = gene_cluster_features
        self.cell_cluster_features = cell_cluster_features
        self.stats_features = stats_features
        
    def __len__(self):
        return (self.gene_features.shape[0])
    
    def __getitem__(self, idx):
        dct = {
            'gene_x' : torch.tensor(self.gene_features[idx, :], dtype=torch.float), 
            'cell_x' : torch.tensor(self.cell_features[idx, :], dtype=torch.float), 
            'gene_pca_x' : torch.tensor(self.gene_pca_features[idx, :], dtype=torch.float), 
            'cell_pca_x' : torch.tensor(self.cell_pca_features[idx, :], dtype=torch.float), 
            'gene_cluster_x' : torch.tensor(self.gene_cluster_features[idx, :], dtype=torch.float), 
            'cell_cluster_x' : torch.tensor(self.cell_cluster_features[idx, :], dtype=torch.float), 
            'stats_x' : torch.tensor(self.stats_features[idx, :], dtype=torch.float)
        }
        
        return dct

# %%
# 7-head pytorch learning network
def train_fn(model, optimizer, scheduler, loss_fn, dataloader, device):
    model.train()
    final_loss = 0
    
    for data in dataloader:
        optimizer.zero_grad()
        gene_x = data['gene_x'].to(device)
        cell_x = data['cell_x'].to(device)
        gene_pca_x = data['gene_pca_x'].to(device)
        cell_pca_x = data['cell_pca_x'].to(device)
        gene_cluster_x = data['gene_cluster_x'].to(device)
        cell_cluster_x = data['cell_cluster_x'].to(device)
        stats_x = data['stats_x'].to(device)
        targets = data['y'].to(device)
        
        outputs = model(gene_x, cell_x, gene_pca_x, cell_pca_x, gene_cluster_x, cell_cluster_x, stats_x)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        final_loss += loss.item()
    
    final_loss /= len(dataloader)
    
    return final_loss

def valid_fn(model, loss_fn, dataloader, device):
    model.eval()
    final_loss = 0
    valid_preds = []
    
    for data in dataloader:
        gene_x = data['gene_x'].to(device)
        cell_x = data['cell_x'].to(device)
        gene_pca_x = data['gene_pca_x'].to(device)
        cell_pca_x = data['cell_pca_x'].to(device)
        gene_cluster_x = data['gene_cluster_x'].to(device)
        cell_cluster_x = data['cell_cluster_x'].to(device)
        stats_x = data['stats_x'].to(device)
        targets = data['y'].to(device)
        outputs = model(gene_x, cell_x, gene_pca_x, cell_pca_x, gene_cluster_x, cell_cluster_x, stats_x)
        loss = loss_fn(outputs, targets)
        
        final_loss += loss.item()
        valid_preds.append(outputs.sigmoid().detach().cpu().numpy())
    
    final_loss /= len(dataloader)
    valid_preds = np.concatenate(valid_preds)
    
    return final_loss, valid_preds

def test_fn(model, dataloader, device):
    model.eval()
    preds = []
    
    for data in dataloader:
        gene_x = data['gene_x'].to(device)
        cell_x = data['cell_x'].to(device)
        gene_pca_x = data['gene_pca_x'].to(device)
        cell_pca_x = data['cell_pca_x'].to(device)
        gene_cluster_x = data['gene_cluster_x'].to(device)
        cell_cluster_x = data['cell_cluster_x'].to(device)
        stats_x = data['stats_x'].to(device)
        
        with torch.no_grad():
            outputs = model(gene_x, cell_x, gene_pca_x, cell_pca_x, gene_cluster_x, cell_cluster_x, stats_x)
        
        preds.append(outputs.sigmoid().detach().cpu().numpy())
        
    preds = np.concatenate(preds)
    
    return preds

# %%
# 7-head pytorch hyper-parameter
EPOCHS                   = 25
BATCH_SIZE               = 128
LEARNING_RATE            = 1e-3
WEIGHT_DECAY             = 1e-5
EARLY_STOP               = True
EARLY_STOPPING_STEPS     = 10

gene_hidden_size         = 1024
cell_hidden_size         = 512
gene_pca_hidden_size     = 156
cell_pca_hidden_size     = 8
gene_cluster_hidden_size = 35
cell_cluster_hidden_size = 5
stats_hidden_size        = 15

DEVICE = ('cuda' if torch.cuda.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda

# %%
# 7-head training function
def run_training(fold, seed, seed_idx):
    seed_everything(seed)
    
    # training
    train_idx = np.where(train['kfold'] != fold)[0]
    valid_idx = np.where(train['kfold'] == fold)[0]
    
    train_df = train[train['kfold'] != fold]
    valid_df = train[train['kfold'] == fold]
    
    gene_x_train = train_df[gene_cols + cpoh_cols].values
    cell_x_train = train_df[cell_cols + cpoh_cols].values
    gene_pca_x_train = train_df[gene_pca_cols + cpoh_cols].values
    cell_pca_x_train = train_df[cell_pca_cols + cpoh_cols].values
    gene_cluster_x_train = train_df[gene_cluster_cols + cpoh_cols].values
    cell_cluster_x_train = train_df[cell_cluster_cols + cpoh_cols].values
    stats_x_train = train_df[stats_cols + cpoh_cols].values
    y_train = train_df[target_cols].values
    
    gene_x_valid = valid_df[gene_cols + cpoh_cols].values
    cell_x_valid = valid_df[cell_cols + cpoh_cols].values
    gene_pca_x_valid = valid_df[gene_pca_cols + cpoh_cols].values
    cell_pca_x_valid = valid_df[cell_pca_cols + cpoh_cols].values
    gene_cluster_x_valid = valid_df[gene_cluster_cols + cpoh_cols].values
    cell_cluster_x_valid = valid_df[cell_cluster_cols + cpoh_cols].values
    stats_x_valid = valid_df[stats_cols + cpoh_cols].values
    y_valid = valid_df[target_cols].values
    
    train_dataset = TrainDataSet(gene_x_train, cell_x_train, gene_pca_x_train, cell_pca_x_train, 
                                 gene_cluster_x_train, cell_cluster_x_train, stats_x_train, y_train)
    valid_dataset = TrainDataSet(gene_x_valid, cell_x_valid, gene_pca_x_valid, cell_pca_x_valid, 
                                 gene_cluster_x_valid, cell_cluster_x_valid, stats_x_valid, y_valid)
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = Model(
        num_gene_features=len(gene_cols + cpoh_cols), 
        num_cell_features=len(cell_cols + cpoh_cols), 
        num_gene_pca_features=len(gene_pca_cols + cpoh_cols), 
        num_cell_pca_features=len(cell_pca_cols + cpoh_cols), 
        num_gene_cluster_features=len(gene_cluster_cols + cpoh_cols), 
        num_cell_cluster_features=len(cell_cluster_cols + cpoh_cols), 
        num_stats_features=len(stats_cols + cpoh_cols), 
        num_targets=len(target_cols), 
        gene_hidden_size=gene_hidden_size, 
        cell_hidden_size=cell_hidden_size, 
        gene_pca_hidden_size=gene_pca_hidden_size, 
        cell_pca_hidden_size=cell_pca_hidden_size, 
        gene_cluster_hidden_size=gene_cluster_hidden_size, 
        cell_cluster_hidden_size=cell_cluster_hidden_size, 
        stats_hidden_size=stats_hidden_size
    )
    model.to(DEVICE)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                                    max_lr=1e-2, epochs=EPOCHS, steps_per_epoch=len(trainloader))
    loss_fn = nn.BCEWithLogitsLoss()
    
    early_step = 0
    early_stopping_steps = EARLY_STOPPING_STEPS
    
    oof = np.zeros((train.shape[0], len(target_cols)))
    best_loss = np.inf
    
    for epoch in range(EPOCHS):
        start = time.time()
        train_loss = train_fn(model, optimizer, scheduler, loss_fn, trainloader, DEVICE)
        valid_loss, valid_preds = valid_fn(model, loss_fn, validloader, DEVICE)
        
        elapse = time.time() - start
        print(f"seed: {seed_idx}, fold: {fold}, epoch: {epoch}, train_loss: {train_loss}, valid_loss: {valid_loss}, elapse: {elapse:0.2f} sec")
        
        if valid_loss < best_loss:
            best_loss = valid_loss
            oof[valid_idx] = valid_preds
            torch.save(model.state_dict(), f"{path_output}/seed{seed_idx}-fold{fold}.pth")
        elif(EARLY_STOP == True):
            early_step += 1
            if (early_step >= early_stopping_steps):
                break
    
    # prediction
    gene_x_test = test[gene_cols + cpoh_cols].values
    cell_x_test = test[cell_cols + cpoh_cols].values
    gene_pca_x_test = test[gene_pca_cols + cpoh_cols].values
    cell_pca_x_test = test[cell_pca_cols + cpoh_cols].values
    gene_cluster_x_test = test[gene_cluster_cols + cpoh_cols].values
    cell_cluster_x_test = test[cell_cluster_cols + cpoh_cols].values
    stats_x_test = test[stats_cols + cpoh_cols].values
    
    test_dataset = TestDataSet(gene_x_test, cell_x_test, gene_pca_x_test, cell_pca_x_test, 
                               gene_cluster_x_test, cell_cluster_x_test, stats_x_test)
    testloader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = Model(
        num_gene_features=len(gene_cols + cpoh_cols), 
        num_cell_features=len(cell_cols + cpoh_cols), 
        num_gene_pca_features=len(gene_pca_cols + cpoh_cols), 
        num_cell_pca_features=len(cell_pca_cols + cpoh_cols), 
        num_gene_cluster_features=len(gene_cluster_cols + cpoh_cols), 
        num_cell_cluster_features=len(cell_cluster_cols + cpoh_cols), 
        num_stats_features=len(stats_cols + cpoh_cols), 
        num_targets=len(target_cols), 
        gene_hidden_size=gene_hidden_size, 
        cell_hidden_size=cell_hidden_size, 
        gene_pca_hidden_size=gene_pca_hidden_size, 
        cell_pca_hidden_size=cell_pca_hidden_size, 
        gene_cluster_hidden_size=gene_cluster_hidden_size, 
        cell_cluster_hidden_size=cell_cluster_hidden_size, 
        stats_hidden_size=stats_hidden_size
    )
    model.load_state_dict(torch.load(f"{path_output}/seed{seed_idx}-fold{fold}.pth"))
    model.to(DEVICE)
    
    pred = np.zeros((test.shape[0], len(target_cols)))
    pred = test_fn(model, testloader, DEVICE)
    
    return oof, pred

# %%
def run_kfold(num_fold, seed, seed_idx):
    oof = np.zeros((train.shape[0], len(target_cols)))
    pred = np.zeros((test.shape[0], len(target_cols)))
    
    for fold in range(num_fold):
        oof_, pred_ = run_training(fold, seed, seed_idx)
        
        oof += oof_
        pred += pred_ / num_fold
        
    return oof, pred

# %%
# %%time

# start calculation on multiple seeds
oof = np.zeros((train.shape[0], len(target_cols)))
pred = np.zeros((test.shape[0], len(target_cols)))

for idx, seed in enumerate(model_seeds):
    oof_, pred_ = run_kfold(num_fold, seed, idx)
    oof += oof_ / len(model_seeds)
    pred += pred_ / len(model_seeds)
# Out:
# seed: 0, fold: 0, epoch: 0, train_loss: 0.47928728122750053, valid_loss: 0.02427878874753203, elapse: 5.37 sec
# seed: 0, fold: 0, epoch: 1, train_loss: 0.020743040435448074, valid_loss: 0.019137578617249216, elapse: 4.42 sec
# seed: 0, fold: 0, epoch: 2, train_loss: 0.018492117497152176, valid_loss: 0.018708557954856327, elapse: 3.83 sec
# seed: 0, fold: 0, epoch: 3, train_loss: 0.017567428503779396, valid_loss: 0.017998169868120126, elapse: 4.43 sec
# seed: 0, fold: 0, epoch: 4, train_loss: 0.017091220325749855, valid_loss: 0.01766360950257097, elapse: 4.11 sec
# seed: 0, fold: 0, epoch: 5, train_loss: 0.01688156658918529, valid_loss: 0.017925729363092353, elapse: 4.77 sec
# seed: 0, fold: 0, epoch: 6, train_loss: 0.017046048852574568, valid_loss: 0.017943310711000648, elapse: 4.95 sec
# seed: 0, fold: 0, epoch: 7, train_loss: 0.017049757250841114, valid_loss: 0.01808332505502871, elapse: 4.68 sec
# seed: 0, fold: 0, epoch: 8, train_loss: 0.017143429182739794, valid_loss: 0.01789156049489975, elapse: 4.83 sec
# seed: 0, fold: 0, epoch: 9, train_loss: 0.01722688632139909, valid_loss: 0.017807044461369513, elapse: 4.80 sec
# seed: 0, fold: 0, epoch: 10, train_loss: 0.017179972856588985, valid_loss: 0.017743906511792116, elapse: 4.58 sec
# seed: 0, fold: 0, epoch: 11, train_loss: 0.017152227366856045, valid_loss: 0.017786629338349614, elapse: 4.92 sec
# seed: 0, fold: 0, epoch: 12, train_loss: 0.017105397802062224, valid_loss: 0.017711117783827442, elapse: 4.93 sec
# seed: 0, fold: 0, epoch: 13, train_loss: 0.016916550554173147, valid_loss: 0.01746713827763285, elapse: 4.79 sec
# seed: 0, fold: 0, epoch: 14, train_loss: 0.01679438760207183, valid_loss: 0.01752469465136528, elapse: 4.07 sec
# seed: 0, fold: 0, epoch: 15, train_loss: 0.016645736250000587, valid_loss: 0.017274683501039233, elapse: 4.78 sec
# seed: 0, fold: 0, epoch: 16, train_loss: 0.016466516414252313, valid_loss: 0.01729481350630522, elapse: 4.13 sec
# seed: 0, fold: 1, epoch: 0, train_loss: 0.4826676150661533, valid_loss: 0.025325251264231546, elapse: 4.46 sec
# seed: 0, fold: 1, epoch: 1, train_loss: 0.020692429756813676, valid_loss: 0.019104046640651566, elapse: 4.90 sec
# seed: 0, fold: 1, epoch: 2, train_loss: 0.0183964664062118, valid_loss: 0.018407696645174706, elapse: 4.78 sec
# seed: 0, fold: 1, epoch: 3, train_loss: 0.017472024028101107, valid_loss: 0.017980151091303145, elapse: 4.77 sec
# seed: 0, fold: 1, epoch: 4, train_loss: 0.016986824429328858, valid_loss: 0.01800683404185942, elapse: 4.79 sec
# seed: 0, fold: 1, epoch: 5, train_loss: 0.016941759517810642, valid_loss: 0.01804752852767706, elapse: 4.77 sec
# seed: 0, fold: 1, epoch: 6, train_loss: 0.016972985812021, valid_loss: 0.01782761761652572, elapse: 4.79 sec
# seed: 0, fold: 1, epoch: 7, train_loss: 0.017011851908462328, valid_loss: 0.018117984064987727, elapse: 4.89 sec
# seed: 0, fold: 1, epoch: 8, train_loss: 0.01705510293670597, valid_loss: 0.018007123257432665, elapse: 4.83 sec
# seed: 0, fold: 1, epoch: 9, train_loss: 0.017109484622513292, valid_loss: 0.017880015527563436, elapse: 4.81 sec
# seed: 0, fold: 1, epoch: 10, train_loss: 0.01710008934520892, valid_loss: 0.01794305198958942, elapse: 4.59 sec
# seed: 0, fold: 1, epoch: 11, train_loss: 0.016991790873508383, valid_loss: 0.017832079343497752, elapse: 4.76 sec
# seed: 0, fold: 1, epoch: 12, train_loss: 0.017003493050426026, valid_loss: 0.01777500103094748, elapse: 4.35 sec
# seed: 0, fold: 1, epoch: 13, train_loss: 0.016886476522488314, valid_loss: 0.01782982682010957, elapse: 4.79 sec
# seed: 0, fold: 1, epoch: 14, train_loss: 0.016737816420240994, valid_loss: 0.017787928692996502, elapse: 4.56 sec
# seed: 0, fold: 1, epoch: 15, train_loss: 0.016590498530571044, valid_loss: 0.017529695481061935, elapse: 4.81 sec
# seed: 0, fold: 1, epoch: 16, train_loss: 0.01651176294298285, valid_loss: 0.01747793278523854, elapse: 4.78 sec
# seed: 0, fold: 1, epoch: 17, train_loss: 0.016288218027266273, valid_loss: 0.01743814934577261, elapse: 4.76 sec
# seed: 0, fold: 1, epoch: 18, train_loss: 0.016030775417104688, valid_loss: 0.017336011837635723, elapse: 4.76 sec
# seed: 0, fold: 1, epoch: 19, train_loss: 0.015705111402555975, valid_loss: 0.01733171585947275, elapse: 4.86 sec
# seed: 0, fold: 1, epoch: 20, train_loss: 0.015401483071546485, valid_loss: 0.01731031443923712, elapse: 4.71 sec
# seed: 0, fold: 1, epoch: 21, train_loss: 0.015110290371371012, valid_loss: 0.017274357431701252, elapse: 4.82 sec
# seed: 0, fold: 1, epoch: 22, train_loss: 0.014810562698020988, valid_loss: 0.01719909528536456, elapse: 4.77 sec
# seed: 0, fold: 1, epoch: 23, train_loss: 0.014565306042667724, valid_loss: 0.01721253227442503, elapse: 4.69 sec
# seed: 0, fold: 2, epoch: 0, train_loss: 0.4808306600223633, valid_loss: 0.024688775464892388, elapse: 4.68 sec
# seed: 0, fold: 2, epoch: 1, train_loss: 0.020646360365376957, valid_loss: 0.01890317156378712, elapse: 4.92 sec
# seed: 0, fold: 2, epoch: 2, train_loss: 0.01845157753838145, valid_loss: 0.01868034675717354, elapse: 4.85 sec
# seed: 0, fold: 2, epoch: 3, train_loss: 0.017510290001181587, valid_loss: 0.017890276147850923, elapse: 4.79 sec
# seed: 0, fold: 2, epoch: 4, train_loss: 0.01702231512931378, valid_loss: 0.01792954302259854, elapse: 4.83 sec
# seed: 0, fold: 2, epoch: 5, train_loss: 0.016892308193812336, valid_loss: 0.017897617045257774, elapse: 4.72 sec
# seed: 0, fold: 2, epoch: 6, train_loss: 0.01700218795272319, valid_loss: 0.017964249210698262, elapse: 4.04 sec
# seed: 0, fold: 2, epoch: 7, train_loss: 0.017110272445648476, valid_loss: 0.017811790401382106, elapse: 4.87 sec
# seed: 0, fold: 2, epoch: 8, train_loss: 0.017113921185280535, valid_loss: 0.01782287447048085, elapse: 4.83 sec
# seed: 0, fold: 2, epoch: 9, train_loss: 0.01714690212511282, valid_loss: 0.01778406013867685, elapse: 4.77 sec
# seed: 0, fold: 2, epoch: 10, train_loss: 0.017029397203114586, valid_loss: 0.017669668341321606, elapse: 4.87 sec
# seed: 0, fold: 2, epoch: 11, train_loss: 0.01709987287261132, valid_loss: 0.01763026261968272, elapse: 4.79 sec
# seed: 0, fold: 2, epoch: 12, train_loss: 0.016965027291165745, valid_loss: 0.01781832261809281, elapse: 4.74 sec
# seed: 0, fold: 2, epoch: 13, train_loss: 0.016900261445645836, valid_loss: 0.017523757022406373, elapse: 4.88 sec
# seed: 0, fold: 2, epoch: 14, train_loss: 0.01683502831239847, valid_loss: 0.0175904155043619, elapse: 4.84 sec
# seed: 0, fold: 2, epoch: 15, train_loss: 0.016667958706671347, valid_loss: 0.017597767072064535, elapse: 4.37 sec
# seed: 0, fold: 2, epoch: 16, train_loss: 0.016564920335414186, valid_loss: 0.017294381133147647, elapse: 4.32 sec
# seed: 0, fold: 2, epoch: 17, train_loss: 0.016281075674392607, valid_loss: 0.017531030172748225, elapse: 4.84 sec
# seed: 0, fold: 2, epoch: 18, train_loss: 0.016062284374366635, valid_loss: 0.01727165332330125, elapse: 4.81 sec
# seed: 0, fold: 2, epoch: 19, train_loss: 0.015763259297101827, valid_loss: 0.01734493803232908, elapse: 4.89 sec
# seed: 0, fold: 2, epoch: 20, train_loss: 0.015447434760036243, valid_loss: 0.01724805829248258, elapse: 4.40 sec
# seed: 0, fold: 2, epoch: 21, train_loss: 0.01515528610974982, valid_loss: 0.017265840619802474, elapse: 3.86 sec
# seed: 0, fold: 3, epoch: 0, train_loss: 0.4815075986114317, valid_loss: 0.02444112098642758, elapse: 4.36 sec
# seed: 0, fold: 3, epoch: 1, train_loss: 0.020747186629560547, valid_loss: 0.019854109255330904, elapse: 4.71 sec
# seed: 0, fold: 3, epoch: 2, train_loss: 0.01854898642235692, valid_loss: 0.018000602456075803, elapse: 4.80 sec
# seed: 0, fold: 3, epoch: 3, train_loss: 0.017591969541989376, valid_loss: 0.017822155063705786, elapse: 4.95 sec
# seed: 0, fold: 3, epoch: 4, train_loss: 0.017086022486235353, valid_loss: 0.017804834273244655, elapse: 4.55 sec
# seed: 0, fold: 3, epoch: 5, train_loss: 0.017059165404002735, valid_loss: 0.017819518755589212, elapse: 4.75 sec
# seed: 0, fold: 3, epoch: 6, train_loss: 0.01707004379157139, valid_loss: 0.017639320716261862, elapse: 4.85 sec
# seed: 0, fold: 3, epoch: 7, train_loss: 0.017162032222942165, valid_loss: 0.017828668068562235, elapse: 4.85 sec
# seed: 0, fold: 3, epoch: 8, train_loss: 0.017178031771133345, valid_loss: 0.017681344226002694, elapse: 4.80 sec
# seed: 0, fold: 3, epoch: 9, train_loss: 0.01724689242605498, valid_loss: 0.017566570613001074, elapse: 4.67 sec
# seed: 0, fold: 3, epoch: 10, train_loss: 0.017135386989600418, valid_loss: 0.018059404061308928, elapse: 4.63 sec
# seed: 0, fold: 3, epoch: 11, train_loss: 0.01713587351791237, valid_loss: 0.017466313152440956, elapse: 4.77 sec
# seed: 0, fold: 3, epoch: 12, train_loss: 0.017097533505032028, valid_loss: 0.017577153098370348, elapse: 4.87 sec
# seed: 0, fold: 3, epoch: 13, train_loss: 0.01697466371284015, valid_loss: 0.017341869457491808, elapse: 4.60 sec
# seed: 0, fold: 3, epoch: 14, train_loss: 0.016869566565298515, valid_loss: 0.017427378121231282, elapse: 4.59 sec
# seed: 0, fold: 3, epoch: 15, train_loss: 0.01670604402307367, valid_loss: 0.017352945996182305, elapse: 4.76 sec
# seed: 0, fold: 3, epoch: 16, train_loss: 0.0164680582727643, valid_loss: 0.017198865009205682, elapse: 4.82 sec
# seed: 0, fold: 3, epoch: 17, train_loss: 0.016351096318575783, valid_loss: 0.017102815929268086, elapse: 4.80 sec
# seed: 0, fold: 3, epoch: 18, train_loss: 0.016111774518545986, valid_loss: 0.017115625739097595, elapse: 4.61 sec
# seed: 0, fold: 3, epoch: 19, train_loss: 0.01576050794750884, valid_loss: 0.017051728442311287, elapse: 4.77 sec
# seed: 0, fold: 3, epoch: 20, train_loss: 0.015509522722467133, valid_loss: 0.0169441143316882, elapse: 4.54 sec
# seed: 0, fold: 3, epoch: 21, train_loss: 0.015088898183750933, valid_loss: 0.01691747752151319, elapse: 4.51 sec
# seed: 0, fold: 3, epoch: 22, train_loss: 0.014848355359087387, valid_loss: 0.016855545581451484, elapse: 4.26 sec
# seed: 0, fold: 3, epoch: 23, train_loss: 0.014571328438224567, valid_loss: 0.016881761460431983, elapse: 4.19 sec
# seed: 0, fold: 3, epoch: 24, train_loss: 0.014532464158221863, valid_loss: 0.016847818344831466, elapse: 4.82 sec
# seed: 0, fold: 4, epoch: 0, train_loss: 0.48117683672656614, valid_loss: 0.02492047425891672, elapse: 4.66 sec
# seed: 0, fold: 4, epoch: 1, train_loss: 0.020710482572515804, valid_loss: 0.019229819891708237, elapse: 4.81 sec
# seed: 0, fold: 4, epoch: 2, train_loss: 0.018371307378823774, valid_loss: 0.01835661658218929, elapse: 4.91 sec
# seed: 0, fold: 4, epoch: 3, train_loss: 0.017405940806898085, valid_loss: 0.018086009765309947, elapse: 4.75 sec
# seed: 0, fold: 4, epoch: 4, train_loss: 0.016954138787274343, valid_loss: 0.01823603356523173, elapse: 4.82 sec
# seed: 0, fold: 4, epoch: 5, train_loss: 0.01694649283139818, valid_loss: 0.017894404434732027, elapse: 4.79 sec
# seed: 0, fold: 4, epoch: 6, train_loss: 0.01697304252319146, valid_loss: 0.018071637355855534, elapse: 4.70 sec
# seed: 0, fold: 4, epoch: 7, train_loss: 0.017052782267548035, valid_loss: 0.0179409601858684, elapse: 4.79 sec
# seed: 0, fold: 4, epoch: 8, train_loss: 0.017095278401899595, valid_loss: 0.018083071362759384, elapse: 4.92 sec
# seed: 0, fold: 4, epoch: 9, train_loss: 0.01709748465783786, valid_loss: 0.017979588865169458, elapse: 4.81 sec
# seed: 0, fold: 4, epoch: 10, train_loss: 0.017007251155387232, valid_loss: 0.018065180762537887, elapse: 4.78 sec
# seed: 0, fold: 4, epoch: 11, train_loss: 0.016962971308848995, valid_loss: 0.018047228907900198, elapse: 4.73 sec
# seed: 0, fold: 4, epoch: 12, train_loss: 0.016944683953255848, valid_loss: 0.01788108234426805, elapse: 4.82 sec
# seed: 0, fold: 4, epoch: 13, train_loss: 0.016906112412233717, valid_loss: 0.017772990332118103, elapse: 4.74 sec
# seed: 0, fold: 4, epoch: 14, train_loss: 0.016751944478871166, valid_loss: 0.01761930337441819, elapse: 4.85 sec
# seed: 0, fold: 4, epoch: 15, train_loss: 0.016638790554218533, valid_loss: 0.017780576912420135, elapse: 4.91 sec
# seed: 0, fold: 4, epoch: 16, train_loss: 0.016450963482476662, valid_loss: 0.017526734593723503, elapse: 4.79 sec
# seed: 0, fold: 4, epoch: 17, train_loss: 0.016217820839011583, valid_loss: 0.0174494845526559, elapse: 4.83 sec
# seed: 0, fold: 4, epoch: 18, train_loss: 0.016027371324868738, valid_loss: 0.01756113576037543, elapse: 4.84 sec
# seed: 0, fold: 4, epoch: 19, train_loss: 0.01571359467841145, valid_loss: 0.017412335452224526, elapse: 4.57 sec
# seed: 0, fold: 4, epoch: 20, train_loss: 0.015435861214401497, valid_loss: 0.017263549220349107, elapse: 4.63 sec
# seed: 0, fold: 4, epoch: 21, train_loss: 0.01511466167057338, valid_loss: 0.017294091119297913, elapse: 4.91 sec
# seed: 1, fold: 0, epoch: 0, train_loss: 0.48170673492216115, valid_loss: 0.025960246633206095, elapse: 4.20 sec
# seed: 1, fold: 0, epoch: 1, train_loss: 0.02074530753104583, valid_loss: 0.019017134979367255, elapse: 4.61 sec
# seed: 1, fold: 0, epoch: 2, train_loss: 0.018502472150746897, valid_loss: 0.018130228295922278, elapse: 4.81 sec
# seed: 1, fold: 0, epoch: 3, train_loss: 0.01751347594772992, valid_loss: 0.017831930544759546, elapse: 4.78 sec
# seed: 1, fold: 0, epoch: 4, train_loss: 0.017092949292366055, valid_loss: 0.017829450352915697, elapse: 4.72 sec
# seed: 1, fold: 0, epoch: 5, train_loss: 0.017105565386135942, valid_loss: 0.017710906639695167, elapse: 4.91 sec
# seed: 1, fold: 0, epoch: 6, train_loss: 0.01700161989994239, valid_loss: 0.01786055647368942, elapse: 4.82 sec
# seed: 1, fold: 0, epoch: 7, train_loss: 0.0171592495188225, valid_loss: 0.017926718374448165, elapse: 4.80 sec
# seed: 1, fold: 0, epoch: 8, train_loss: 0.017135028862326904, valid_loss: 0.017716139688023498, elapse: 4.77 sec
# seed: 1, fold: 0, epoch: 9, train_loss: 0.017103216320654188, valid_loss: 0.01762908957898617, elapse: 4.25 sec
# seed: 1, fold: 0, epoch: 10, train_loss: 0.01722318460435971, valid_loss: 0.017599623543875557, elapse: 4.22 sec
# seed: 1, fold: 0, epoch: 11, train_loss: 0.01705093217500742, valid_loss: 0.017596036621502466, elapse: 4.45 sec
# seed: 1, fold: 0, epoch: 12, train_loss: 0.016963024441476748, valid_loss: 0.017804338836244174, elapse: 4.80 sec
# seed: 1, fold: 0, epoch: 13, train_loss: 0.016943786799421778, valid_loss: 0.017506720764296397, elapse: 4.79 sec
# seed: 1, fold: 0, epoch: 14, train_loss: 0.016790209027628105, valid_loss: 0.017602582462131977, elapse: 4.83 sec
# seed: 1, fold: 0, epoch: 15, train_loss: 0.016618530448202207, valid_loss: 0.017320003945912633, elapse: 4.82 sec
# seed: 1, fold: 0, epoch: 16, train_loss: 0.01648069153526339, valid_loss: 0.017333478666841984, elapse: 4.83 sec
# seed: 1, fold: 0, epoch: 17, train_loss: 0.016262426574215078, valid_loss: 0.017432422350559917, elapse: 4.92 sec
# seed: 1, fold: 0, epoch: 18, train_loss: 0.01612713901946942, valid_loss: 0.017190370336174966, elapse: 4.77 sec
# seed: 1, fold: 0, epoch: 19, train_loss: 0.015759435036908024, valid_loss: 0.01707641862865005, elapse: 4.86 sec
# seed: 1, fold: 0, epoch: 20, train_loss: 0.015430794137975445, valid_loss: 0.017115141664232527, elapse: 4.41 sec
# seed: 1, fold: 0, epoch: 21, train_loss: 0.01512668538244738, valid_loss: 0.017019510455429553, elapse: 4.38 sec
# seed: 1, fold: 0, epoch: 22, train_loss: 0.01480829733275417, valid_loss: 0.017061690853110382, elapse: 4.47 sec
# seed: 1, fold: 0, epoch: 23, train_loss: 0.014582859669420599, valid_loss: 0.017041258460709027, elapse: 4.94 sec
# seed: 1, fold: 1, epoch: 0, train_loss: 0.4817369878971881, valid_loss: 0.025874052090304238, elapse: 4.70 sec
# seed: 1, fold: 1, epoch: 1, train_loss: 0.020763418929529015, valid_loss: 0.019106063885348183, elapse: 4.62 sec
# seed: 1, fold: 1, epoch: 2, train_loss: 0.018393093658896693, valid_loss: 0.018365201354026795, elapse: 4.80 sec
# seed: 1, fold: 1, epoch: 3, train_loss: 0.017442833693412534, valid_loss: 0.017971953217472348, elapse: 4.78 sec
# seed: 1, fold: 1, epoch: 4, train_loss: 0.01700999033059517, valid_loss: 0.017958632058330943, elapse: 4.75 sec
# seed: 1, fold: 1, epoch: 5, train_loss: 0.01693682155034838, valid_loss: 0.01789508169250829, elapse: 4.89 sec
# seed: 1, fold: 1, epoch: 6, train_loss: 0.01704592119739221, valid_loss: 0.017912547050842217, elapse: 4.81 sec
# seed: 1, fold: 1, epoch: 7, train_loss: 0.017081768224763608, valid_loss: 0.017972203849681786, elapse: 4.71 sec
# seed: 1, fold: 1, epoch: 8, train_loss: 0.017142907390031065, valid_loss: 0.01794141453823873, elapse: 4.78 sec
# seed: 1, fold: 1, epoch: 9, train_loss: 0.017110573698895692, valid_loss: 0.017948259067322527, elapse: 4.79 sec
# seed: 1, fold: 1, epoch: 10, train_loss: 0.017114900066143406, valid_loss: 0.018023174229477135, elapse: 4.79 sec
# seed: 1, fold: 1, epoch: 11, train_loss: 0.01697977589456922, valid_loss: 0.01773446870169469, elapse: 4.88 sec
# seed: 1, fold: 1, epoch: 12, train_loss: 0.016930685310631337, valid_loss: 0.017674010220382896, elapse: 4.82 sec
# seed: 1, fold: 1, epoch: 13, train_loss: 0.01692552394811472, valid_loss: 0.017626684957316945, elapse: 4.70 sec
# seed: 1, fold: 1, epoch: 14, train_loss: 0.016761611501285193, valid_loss: 0.01784831365304334, elapse: 4.57 sec
# seed: 1, fold: 1, epoch: 15, train_loss: 0.016604240895350918, valid_loss: 0.017537464680416243, elapse: 4.76 sec
# seed: 1, fold: 1, epoch: 16, train_loss: 0.016464400254733808, valid_loss: 0.01762419986937727, elapse: 4.74 sec
# seed: 1, fold: 1, epoch: 17, train_loss: 0.016238103641101915, valid_loss: 0.01738752994154181, elapse: 4.70 sec
# seed: 1, fold: 1, epoch: 18, train_loss: 0.01594853039531812, valid_loss: 0.01746171260518687, elapse: 3.83 sec
# seed: 1, fold: 1, epoch: 19, train_loss: 0.015675830029386238, valid_loss: 0.017423900296645506, elapse: 4.77 sec
# seed: 1, fold: 1, epoch: 20, train_loss: 0.015378768453850363, valid_loss: 0.017357356926160198, elapse: 4.81 sec
# seed: 1, fold: 1, epoch: 21, train_loss: 0.015003566065952725, valid_loss: 0.017288786891315664, elapse: 4.60 sec
# seed: 1, fold: 1, epoch: 22, train_loss: 0.014756450776255479, valid_loss: 0.01730783044227532, elapse: 4.23 sec
# seed: 1, fold: 2, epoch: 0, train_loss: 0.4819252269504511, valid_loss: 0.02607317359319755, elapse: 4.68 sec
# seed: 1, fold: 2, epoch: 1, train_loss: 0.02079394219470197, valid_loss: 0.018982152747256415, elapse: 4.72 sec
# seed: 1, fold: 2, epoch: 2, train_loss: 0.018395407091610243, valid_loss: 0.018278082965740135, elapse: 4.69 sec
# seed: 1, fold: 2, epoch: 3, train_loss: 0.017390313868721325, valid_loss: 0.01808103070195232, elapse: 4.83 sec
# seed: 1, fold: 2, epoch: 4, train_loss: 0.016953394235368225, valid_loss: 0.01798444627118962, elapse: 4.83 sec
# seed: 1, fold: 2, epoch: 5, train_loss: 0.016973622797893873, valid_loss: 0.017763006021933897, elapse: 4.73 sec
# seed: 1, fold: 2, epoch: 6, train_loss: 0.01701396904831779, valid_loss: 0.018162875223372663, elapse: 4.60 sec
# seed: 1, fold: 2, epoch: 7, train_loss: 0.0171440201136621, valid_loss: 0.017802505168531622, elapse: 4.57 sec
# seed: 1, fold: 2, epoch: 8, train_loss: 0.0171293247545111, valid_loss: 0.017820673542363302, elapse: 4.77 sec
# seed: 1, fold: 2, epoch: 9, train_loss: 0.017104593044875757, valid_loss: 0.01781608621988978, elapse: 4.87 sec
# seed: 1, fold: 2, epoch: 10, train_loss: 0.017129852760421192, valid_loss: 0.017872219479509763, elapse: 4.80 sec
# seed: 1, fold: 2, epoch: 11, train_loss: 0.017032113877813452, valid_loss: 0.017941969047699655, elapse: 4.78 sec
# seed: 1, fold: 2, epoch: 12, train_loss: 0.017018387708273054, valid_loss: 0.017790238452809196, elapse: 4.91 sec
# seed: 1, fold: 2, epoch: 13, train_loss: 0.01696617090129766, valid_loss: 0.01783413290977478, elapse: 4.81 sec
# seed: 1, fold: 2, epoch: 14, train_loss: 0.01678762852848656, valid_loss: 0.017683580331504346, elapse: 4.82 sec
# seed: 1, fold: 2, epoch: 15, train_loss: 0.01663694610360308, valid_loss: 0.017496939482433454, elapse: 4.76 sec
# seed: 1, fold: 2, epoch: 16, train_loss: 0.016462334269738716, valid_loss: 0.017389615359050887, elapse: 4.70 sec
# seed: 1, fold: 2, epoch: 17, train_loss: 0.01629291075295296, valid_loss: 0.0173821179994515, elapse: 4.48 sec
# seed: 1, fold: 2, epoch: 18, train_loss: 0.016009746827995, valid_loss: 0.017327084498746054, elapse: 4.90 sec
# seed: 1, fold: 2, epoch: 19, train_loss: 0.01573105968966864, valid_loss: 0.017283242541764464, elapse: 4.22 sec
# seed: 1, fold: 2, epoch: 20, train_loss: 0.015423353795178127, valid_loss: 0.017122547142207623, elapse: 4.74 sec
# seed: 1, fold: 2, epoch: 21, train_loss: nan, valid_loss: nan, elapse: 4.76 sec
# seed: 1, fold: 2, epoch: 22, train_loss: nan, valid_loss: nan, elapse: 4.81 sec
# seed: 1, fold: 3, epoch: 0, train_loss: 0.480713142298054, valid_loss: 0.025522285699844362, elapse: 4.67 sec
# seed: 1, fold: 3, epoch: 1, train_loss: 0.021172056474007557, valid_loss: 0.019241698778101377, elapse: 4.92 sec
# seed: 1, fold: 3, epoch: 2, train_loss: 0.018483060013934755, valid_loss: 0.018356691779834882, elapse: 4.81 sec
# seed: 1, fold: 3, epoch: 3, train_loss: 0.0174760262252412, valid_loss: 0.017850890968527114, elapse: 4.80 sec
# seed: 1, fold: 3, epoch: 4, train_loss: 0.0171769043714132, valid_loss: 0.017941244052989143, elapse: 4.43 sec
# seed: 1, fold: 3, epoch: 5, train_loss: 0.017023216926263296, valid_loss: 0.01797357172306095, elapse: 4.61 sec
# seed: 1, fold: 3, epoch: 6, train_loss: 0.017111188408149326, valid_loss: 0.017936574587864535, elapse: 4.55 sec
# seed: 1, fold: 3, epoch: 7, train_loss: 0.017230103204053812, valid_loss: 0.017786844899611815, elapse: 4.44 sec
# seed: 1, fold: 3, epoch: 8, train_loss: 0.017203824520381033, valid_loss: 0.01775390042790345, elapse: 4.83 sec
# seed: 1, fold: 3, epoch: 9, train_loss: 0.01722222865572658, valid_loss: 0.017646336502262525, elapse: 4.69 sec
# seed: 1, fold: 3, epoch: 10, train_loss: 0.017256864312820246, valid_loss: 0.01763074690742152, elapse: 4.75 sec
# seed: 1, fold: 3, epoch: 11, train_loss: 0.017190057946288067, valid_loss: 0.01795722051922764, elapse: 4.83 sec
# seed: 1, fold: 3, epoch: 12, train_loss: 0.017113042327210955, valid_loss: 0.017519264774663108, elapse: 4.78 sec
# seed: 1, fold: 3, epoch: 13, train_loss: 0.017051949051033327, valid_loss: 0.017483499752623696, elapse: 4.94 sec
# seed: 1, fold: 3, epoch: 14, train_loss: 0.01696568995417244, valid_loss: 0.017327310943177767, elapse: 4.83 sec
# seed: 1, fold: 3, epoch: 15, train_loss: 0.016799990573655003, valid_loss: 0.017448820333395686, elapse: 4.75 sec
# seed: 1, fold: 3, epoch: 16, train_loss: 0.016617821630738352, valid_loss: 0.01717578319034406, elapse: 4.83 sec
# seed: 1, fold: 3, epoch: 17, train_loss: 0.016403666056314672, valid_loss: 0.01721999419054815, elapse: 4.83 sec
# seed: 1, fold: 3, epoch: 18, train_loss: 0.01617806827298541, valid_loss: 0.01711767640497003, elapse: 4.86 sec
# seed: 1, fold: 3, epoch: 19, train_loss: 0.015932854690143595, valid_loss: 0.01704685113259724, elapse: 4.52 sec
# seed: 1, fold: 3, epoch: 20, train_loss: 0.015583856827646925, valid_loss: 0.0170260775834322, elapse: 4.83 sec
# seed: 1, fold: 3, epoch: 21, train_loss: 0.015336440801890432, valid_loss: 0.016945913673511573, elapse: 4.65 sec
# seed: 1, fold: 3, epoch: 22, train_loss: 0.015030193284315907, valid_loss: 0.016882303463561194, elapse: 4.12 sec
# seed: 1, fold: 3, epoch: 23, train_loss: 0.014837110907757196, valid_loss: 0.016863786030028548, elapse: 4.60 sec
# seed: 1, fold: 3, epoch: 24, train_loss: 0.01475299235460335, valid_loss: 0.016878741633679185, elapse: 4.70 sec
# seed: 1, fold: 4, epoch: 0, train_loss: 0.4819765813999634, valid_loss: 0.025137161889246532, elapse: 4.12 sec
# seed: 1, fold: 4, epoch: 1, train_loss: 0.020672287387044533, valid_loss: 0.01933462444160666, elapse: 4.80 sec
# seed: 1, fold: 4, epoch: 2, train_loss: 0.018412867500244276, valid_loss: 0.018509011662432125, elapse: 4.34 sec
# seed: 1, fold: 4, epoch: 3, train_loss: 0.01747764902783261, valid_loss: 0.018143111041613987, elapse: 4.74 sec
# seed: 1, fold: 4, epoch: 4, train_loss: 0.017014802696750216, valid_loss: 0.01814027904931988, elapse: 4.38 sec
# seed: 1, fold: 4, epoch: 5, train_loss: 0.016909491965898138, valid_loss: 0.01810906015868698, elapse: 4.78 sec
# seed: 1, fold: 4, epoch: 6, train_loss: 0.01695429357578573, valid_loss: 0.018065457524997847, elapse: 4.94 sec
# seed: 1, fold: 4, epoch: 7, train_loss: 0.017036050193659637, valid_loss: 0.01799243355968169, elapse: 4.75 sec
# seed: 1, fold: 4, epoch: 8, train_loss: 0.017097118499594322, valid_loss: 0.018320030266685144, elapse: 4.81 sec
# seed: 1, fold: 4, epoch: 9, train_loss: 0.017227823231909155, valid_loss: 0.018012995113219535, elapse: 4.83 sec
# seed: 1, fold: 4, epoch: 10, train_loss: 0.01708934207757314, valid_loss: 0.01807232637490545, elapse: 4.87 sec
# seed: 1, fold: 4, epoch: 11, train_loss: 0.01703894231468439, valid_loss: 0.01782295195651906, elapse: 4.77 sec
# seed: 1, fold: 4, epoch: 12, train_loss: 0.01695714230257748, valid_loss: 0.01791349739900657, elapse: 4.39 sec
# seed: 1, fold: 4, epoch: 13, train_loss: 0.016894812439230904, valid_loss: 0.01784420958054917, elapse: 4.68 sec
# seed: 1, fold: 4, epoch: 14, train_loss: 0.01675863536344706, valid_loss: 0.01755480207502842, elapse: 4.79 sec
# seed: 1, fold: 4, epoch: 15, train_loss: 0.016597637791942427, valid_loss: 0.01764665065067155, elapse: 4.81 sec
# seed: 1, fold: 4, epoch: 16, train_loss: 0.016499705187490454, valid_loss: 0.01748993918299675, elapse: 4.84 sec
# seed: 1, fold: 4, epoch: 17, train_loss: 0.01626637739304831, valid_loss: 0.017474635211484773, elapse: 4.80 sec
# seed: 1, fold: 4, epoch: 18, train_loss: 0.01602342080972765, valid_loss: 0.017455484292336874, elapse: 4.96 sec
# seed: 1, fold: 4, epoch: 19, train_loss: 0.015778510163173727, valid_loss: 0.01737877071968147, elapse: 4.76 sec
# seed: 1, fold: 4, epoch: 20, train_loss: 0.015474101913202068, valid_loss: 0.017266471391277655, elapse: 4.82 sec
# seed: 1, fold: 4, epoch: 21, train_loss: 0.015179965442613415, valid_loss: 0.017237322138888494, elapse: 4.79 sec
# seed: 1, fold: 4, epoch: 22, train_loss: 0.014893129569194887, valid_loss: 0.01719464244587081, elapse: 4.84 sec
# seed: 1, fold: 4, epoch: 23, train_loss: 0.014669696307754602, valid_loss: 0.017179124243557452, elapse: 4.83 sec
# seed: 1, fold: 4, epoch: 24, train_loss: 0.014558119598128225, valid_loss: 0.017173182059611592, elapse: 4.83 sec
# seed: 2, fold: 0, epoch: 0, train_loss: 0.4822637609111658, valid_loss: 0.024211727774568967, elapse: 4.73 sec
# seed: 2, fold: 0, epoch: 1, train_loss: 0.020736479814555765, valid_loss: 0.01897222894643034, elapse: 4.83 sec
# seed: 2, fold: 0, epoch: 2, train_loss: 0.018428578817596037, valid_loss: 0.018458492415291922, elapse: 4.48 sec
# seed: 2, fold: 0, epoch: 3, train_loss: 0.017515156769018242, valid_loss: 0.017831414086478096, elapse: 4.68 sec
# seed: 2, fold: 0, epoch: 4, train_loss: 0.0170587083608236, valid_loss: 0.017762636366699423, elapse: 4.79 sec
# seed: 2, fold: 0, epoch: 5, train_loss: 0.016966384140423674, valid_loss: 0.017788287864199708, elapse: 4.96 sec
# seed: 2, fold: 0, epoch: 6, train_loss: 0.01705302779927202, valid_loss: 0.017705732504171984, elapse: 4.83 sec
# seed: 2, fold: 0, epoch: 7, train_loss: 0.017111183103659878, valid_loss: 0.017883534410170147, elapse: 4.85 sec
# seed: 2, fold: 0, epoch: 8, train_loss: 0.017162043466300205, valid_loss: 0.017720514509294714, elapse: 4.81 sec
# seed: 2, fold: 0, epoch: 9, train_loss: 0.017181418998085934, valid_loss: 0.017872021161019803, elapse: 4.50 sec
# seed: 2, fold: 0, epoch: 10, train_loss: 0.01720004647538282, valid_loss: 0.01772489438631705, elapse: 4.84 sec
# seed: 2, fold: 0, epoch: 11, train_loss: 0.0170558910223021, valid_loss: 0.017518462027822222, elapse: 4.94 sec
# seed: 2, fold: 0, epoch: 12, train_loss: 0.0169980987245082, valid_loss: 0.017676578329077788, elapse: 4.46 sec
# seed: 2, fold: 0, epoch: 13, train_loss: 0.016982022605404472, valid_loss: 0.017495594253497466, elapse: 4.84 sec
# seed: 2, fold: 0, epoch: 14, train_loss: 0.016844440332573395, valid_loss: 0.017597397257174765, elapse: 3.81 sec
# seed: 2, fold: 0, epoch: 15, train_loss: 0.01670796222363909, valid_loss: 0.017550345723118102, elapse: 4.25 sec
# seed: 2, fold: 0, epoch: 16, train_loss: 0.016464993013473955, valid_loss: 0.01738471183925867, elapse: 4.76 sec
# seed: 2, fold: 0, epoch: 17, train_loss: 0.016359101117089176, valid_loss: 0.01725922700549875, elapse: 4.61 sec
# seed: 2, fold: 0, epoch: 18, train_loss: 0.0160723140368751, valid_loss: 0.017167175215269836, elapse: 4.81 sec
# seed: 2, fold: 0, epoch: 19, train_loss: 0.015770137701453506, valid_loss: 0.017135329065578325, elapse: 4.81 sec
# seed: 2, fold: 0, epoch: 20, train_loss: 0.015440488335393045, valid_loss: 0.01709198345031057, elapse: 4.68 sec
# seed: 2, fold: 0, epoch: 21, train_loss: 0.015112076116644817, valid_loss: 0.017045947377170835, elapse: 4.67 sec
# seed: 2, fold: 0, epoch: 22, train_loss: 0.01486496041542378, valid_loss: 0.017008402810565062, elapse: 4.72 sec
# seed: 2, fold: 0, epoch: 23, train_loss: 0.014614926995304615, valid_loss: 0.016988343479377884, elapse: 4.77 sec
# seed: 2, fold: 0, epoch: 24, train_loss: 0.014504445898953987, valid_loss: 0.017003255470522814, elapse: 4.95 sec
# seed: 2, fold: 1, epoch: 0, train_loss: 0.48332770486926513, valid_loss: 0.024833971687725612, elapse: 4.44 sec
# seed: 2, fold: 1, epoch: 1, train_loss: 0.020651188223575152, valid_loss: 0.019052563181945256, elapse: 4.57 sec
# seed: 2, fold: 1, epoch: 2, train_loss: 0.018487115227447375, valid_loss: 0.018392513373068402, elapse: 4.70 sec
# seed: 2, fold: 1, epoch: 3, train_loss: 0.017442492815754274, valid_loss: 0.018135838822594712, elapse: 4.54 sec
# seed: 2, fold: 1, epoch: 4, train_loss: 0.01699266562333507, valid_loss: 0.01797074271099908, elapse: 4.75 sec
# seed: 2, fold: 1, epoch: 5, train_loss: 0.01694805279754809, valid_loss: 0.01794404677514519, elapse: 4.71 sec
# seed: 2, fold: 1, epoch: 6, train_loss: 0.017026074019933703, valid_loss: 0.017790124831455093, elapse: 4.80 sec
# seed: 2, fold: 1, epoch: 7, train_loss: 0.017127593829684012, valid_loss: 0.017867657728493212, elapse: 4.76 sec
# seed: 2, fold: 1, epoch: 8, train_loss: 0.01713186502456665, valid_loss: 0.017852751431720597, elapse: 4.71 sec
# seed: 2, fold: 1, epoch: 9, train_loss: 0.01706320070491655, valid_loss: 0.01799717444394316, elapse: 4.78 sec
# seed: 2, fold: 1, epoch: 10, train_loss: 0.01710989836086757, valid_loss: 0.017777273724121707, elapse: 4.77 sec
# seed: 2, fold: 1, epoch: 11, train_loss: 0.01704458092903569, valid_loss: 0.01773228222238166, elapse: 4.40 sec
# seed: 2, fold: 1, epoch: 12, train_loss: 0.0170124583626098, valid_loss: 0.017689328454434872, elapse: 4.70 sec
# seed: 2, fold: 1, epoch: 13, train_loss: 0.01686690385405817, valid_loss: 0.01781617570668459, elapse: 4.79 sec
# seed: 2, fold: 1, epoch: 14, train_loss: 0.016768157590914816, valid_loss: 0.017564049629228456, elapse: 4.80 sec
# seed: 2, fold: 1, epoch: 15, train_loss: 0.0166145846261269, valid_loss: 0.01766787791358573, elapse: 4.72 sec
# seed: 2, fold: 1, epoch: 16, train_loss: 0.016401296345530635, valid_loss: 0.01750215645879507, elapse: 4.74 sec
# seed: 2, fold: 1, epoch: 17, train_loss: 0.016293214532091236, valid_loss: 0.017382218688726424, elapse: 4.90 sec
# seed: 2, fold: 1, epoch: 18, train_loss: 0.015970215248963693, valid_loss: 0.01734074968844652, elapse: 4.72 sec
# seed: 2, fold: 1, epoch: 19, train_loss: 0.01570370526182173, valid_loss: 0.01726815306714603, elapse: 4.82 sec
# seed: 2, fold: 1, epoch: 20, train_loss: 0.015375909667434918, valid_loss: 0.017253646094884192, elapse: 4.80 sec
# seed: 2, fold: 1, epoch: 21, train_loss: 0.01508169146730517, valid_loss: 0.017220247563506874, elapse: 4.77 sec
# seed: 2, fold: 1, epoch: 22, train_loss: 0.014769518809107533, valid_loss: 0.017160882029150212, elapse: 4.81 sec
# seed: 2, fold: 1, epoch: 23, train_loss: 0.01456662162757703, valid_loss: 0.017134791825498853, elapse: 4.91 sec
# seed: 2, fold: 1, epoch: 24, train_loss: 0.014434532167213241, valid_loss: 0.0171488848647901, elapse: 4.78 sec
# seed: 2, fold: 2, epoch: 0, train_loss: 0.48173896081583656, valid_loss: 0.02455794039581503, elapse: 4.52 sec
# seed: 2, fold: 2, epoch: 1, train_loss: 0.020668797275942306, valid_loss: 0.018779137091977257, elapse: 4.78 sec
# seed: 2, fold: 2, epoch: 2, train_loss: 0.01839957434171136, valid_loss: 0.018184900949043886, elapse: 4.80 sec
# seed: 2, fold: 2, epoch: 3, train_loss: 0.017441898807073416, valid_loss: 0.01778897321117776, elapse: 4.70 sec
# seed: 2, fold: 2, epoch: 4, train_loss: 0.017037960160793602, valid_loss: 0.01775844408465283, elapse: 4.93 sec
# seed: 2, fold: 2, epoch: 5, train_loss: 0.01695568668588564, valid_loss: 0.017798737809062003, elapse: 4.80 sec
# seed: 2, fold: 2, epoch: 6, train_loss: 0.017096883408131376, valid_loss: 0.017859925303075994, elapse: 4.77 sec
# seed: 2, fold: 2, epoch: 7, train_loss: 0.01711258377906853, valid_loss: 0.01789697033486196, elapse: 4.81 sec
# seed: 2, fold: 2, epoch: 8, train_loss: 0.017134973171936428, valid_loss: 0.017861483645226273, elapse: 4.83 sec
# seed: 2, fold: 2, epoch: 9, train_loss: 0.017092454247176647, valid_loss: 0.017860443597393378, elapse: 4.68 sec
# seed: 2, fold: 2, epoch: 10, train_loss: 0.01709178007086334, valid_loss: 0.017873379348644188, elapse: 4.68 sec
# seed: 2, fold: 2, epoch: 11, train_loss: 0.017099166403700045, valid_loss: 0.01773816541369472, elapse: 4.80 sec
# seed: 2, fold: 2, epoch: 12, train_loss: 0.017066970157126587, valid_loss: 0.017794533632695675, elapse: 4.82 sec
# seed: 2, fold: 2, epoch: 13, train_loss: 0.016951092269163633, valid_loss: 0.017690845685345787, elapse: 4.72 sec
# seed: 2, fold: 2, epoch: 14, train_loss: 0.016803538926161717, valid_loss: 0.01766095321093287, elapse: 4.83 sec
# seed: 2, fold: 2, epoch: 15, train_loss: 0.01664169935806506, valid_loss: 0.017598036330725465, elapse: 4.80 sec
# seed: 2, fold: 2, epoch: 16, train_loss: 0.016546875926787438, valid_loss: 0.01745856606534549, elapse: 4.40 sec
# seed: 2, fold: 2, epoch: 17, train_loss: 0.016291228359214205, valid_loss: 0.017385822268468992, elapse: 4.67 sec
# seed: 2, fold: 2, epoch: 18, train_loss: 0.016045051188194666, valid_loss: 0.017463158337133272, elapse: 4.81 sec
# seed: 2, fold: 2, epoch: 19, train_loss: 0.015775396515601788, valid_loss: 0.01723151526280812, elapse: 4.77 sec
# seed: 2, fold: 2, epoch: 20, train_loss: 0.015492569857641407, valid_loss: 0.017354297425065723, elapse: 4.78 sec
# seed: 2, fold: 2, epoch: 21, train_loss: 0.015134386718273163, valid_loss: 0.017223945020564964, elapse: 4.78 sec
# seed: 2, fold: 2, epoch: 22, train_loss: 0.014916352151582638, valid_loss: 0.01721939324800457, elapse: 4.77 sec
# seed: 2, fold: 2, epoch: 23, train_loss: 0.014688088558614254, valid_loss: 0.017204856633075645, elapse: 4.76 sec
# seed: 2, fold: 2, epoch: 24, train_loss: 0.014574795677934004, valid_loss: 0.017224807292222977, elapse: 4.83 sec
# seed: 2, fold: 3, epoch: 0, train_loss: 0.4824282334226629, valid_loss: 0.024584375960486276, elapse: 4.14 sec
# seed: 2, fold: 3, epoch: 1, train_loss: 0.020749141691603523, valid_loss: 0.01890900055212634, elapse: 4.67 sec
# seed: 2, fold: 3, epoch: 2, train_loss: 0.018485251463193825, valid_loss: 0.01853961534798145, elapse: 4.81 sec
# seed: 2, fold: 3, epoch: 3, train_loss: 0.017560621716783964, valid_loss: 0.017883826260055816, elapse: 4.86 sec
# seed: 2, fold: 3, epoch: 4, train_loss: 0.01711653419972762, valid_loss: 0.01769321813647236, elapse: 4.77 sec
# seed: 2, fold: 3, epoch: 5, train_loss: 0.017009569163285734, valid_loss: 0.017683887588126317, elapse: 4.42 sec
# seed: 2, fold: 3, epoch: 6, train_loss: 0.017112793697827103, valid_loss: 0.017716600213732038, elapse: 4.80 sec
# seed: 2, fold: 3, epoch: 7, train_loss: 0.017117492220216038, valid_loss: 0.018027677120906967, elapse: 4.80 sec
# seed: 2, fold: 3, epoch: 8, train_loss: 0.017269232742272426, valid_loss: 0.017682198488286564, elapse: 4.47 sec
# seed: 2, fold: 3, epoch: 9, train_loss: 0.017219886197236137, valid_loss: 0.017849726123469217, elapse: 4.89 sec
# seed: 2, fold: 3, epoch: 10, train_loss: 0.017245956804549347, valid_loss: 0.01776855548045465, elapse: 4.76 sec
# seed: 2, fold: 3, epoch: 11, train_loss: 0.01716866440045229, valid_loss: 0.017596762467707906, elapse: 4.73 sec
# seed: 2, fold: 3, epoch: 12, train_loss: 0.017109081007378256, valid_loss: 0.01765111139310258, elapse: 4.85 sec
# seed: 2, fold: 3, epoch: 13, train_loss: 0.017048456098722374, valid_loss: 0.017495564105255264, elapse: 4.70 sec
# seed: 2, fold: 3, epoch: 14, train_loss: 0.016915309080935043, valid_loss: 0.017493187742573874, elapse: 4.84 sec
# seed: 2, fold: 3, epoch: 15, train_loss: 0.016780426732493914, valid_loss: 0.017395501982952866, elapse: 3.97 sec
# seed: 2, fold: 3, epoch: 16, train_loss: 0.01657407396081565, valid_loss: 0.017233392862336976, elapse: 4.21 sec
# seed: 2, fold: 3, epoch: 17, train_loss: 0.01642474337764408, valid_loss: 0.017091660228158747, elapse: 4.85 sec
# seed: 2, fold: 3, epoch: 18, train_loss: 0.016126347017352997, valid_loss: 0.01699574730758156, elapse: 4.62 sec
# seed: 2, fold: 3, epoch: 19, train_loss: 0.015915957306498203, valid_loss: 0.017013804295233317, elapse: 4.61 sec
# seed: 2, fold: 3, epoch: 20, train_loss: 0.015503604552182167, valid_loss: 0.016913275154573578, elapse: 4.78 sec
# seed: 2, fold: 3, epoch: 21, train_loss: 0.015201576890936796, valid_loss: 0.01695693957486323, elapse: 4.92 sec
# seed: 2, fold: 3, epoch: 22, train_loss: 0.014938158873954544, valid_loss: 0.016865707428327627, elapse: 4.74 sec
# seed: 2, fold: 3, epoch: 23, train_loss: 0.014773553250816421, valid_loss: 0.016824748340461937, elapse: 4.85 sec
# seed: 2, fold: 3, epoch: 24, train_loss: 0.014615887209125187, valid_loss: 0.016833390455160822, elapse: 4.84 sec
# seed: 2, fold: 4, epoch: 0, train_loss: 0.48251981589187315, valid_loss: 0.024871599514569555, elapse: 4.41 sec
# seed: 2, fold: 4, epoch: 1, train_loss: 0.020620032402592293, valid_loss: 0.019322121569088527, elapse: 4.81 sec
# seed: 2, fold: 4, epoch: 2, train_loss: 0.018346939114448818, valid_loss: 0.018360818922519683, elapse: 4.93 sec
# seed: 2, fold: 4, epoch: 3, train_loss: 0.01732600960151657, valid_loss: 0.018131810373493602, elapse: 4.76 sec
# seed: 2, fold: 4, epoch: 4, train_loss: 0.017023763315671164, valid_loss: 0.01804942547210625, elapse: 4.84 sec
# seed: 2, fold: 4, epoch: 5, train_loss: 0.01692052185535431, valid_loss: 0.018212444654532842, elapse: 4.83 sec
# seed: 2, fold: 4, epoch: 6, train_loss: 0.017049696505663618, valid_loss: 0.01803032441862992, elapse: 4.78 sec
# seed: 2, fold: 4, epoch: 7, train_loss: 0.01707882164856014, valid_loss: 0.018129583847309862, elapse: 4.83 sec
# seed: 2, fold: 4, epoch: 8, train_loss: 0.01715669551513333, valid_loss: 0.018029804900288583, elapse: 4.92 sec
# seed: 2, fold: 4, epoch: 9, train_loss: 0.017068536965635376, valid_loss: 0.01788059350635324, elapse: 4.47 sec
# seed: 2, fold: 4, epoch: 10, train_loss: 0.017093592188388542, valid_loss: 0.01806767444525446, elapse: 4.77 sec
# seed: 2, fold: 4, epoch: 11, train_loss: 0.016992033452497446, valid_loss: 0.017988332893167223, elapse: 4.85 sec
# seed: 2, fold: 4, epoch: 12, train_loss: 0.01698798928544789, valid_loss: 0.017673089993851525, elapse: 4.87 sec
# seed: 2, fold: 4, epoch: 13, train_loss: 0.01689044997581969, valid_loss: 0.017788390229855264, elapse: 4.61 sec
# seed: 2, fold: 4, epoch: 14, train_loss: 0.016783201000720695, valid_loss: 0.0177094682518925, elapse: 4.92 sec
# seed: 2, fold: 4, epoch: 15, train_loss: 0.016639636579793, valid_loss: 0.017670090975505964, elapse: 4.80 sec
# seed: 2, fold: 4, epoch: 16, train_loss: 0.016465901741353067, valid_loss: 0.017557385191321374, elapse: 4.78 sec
# seed: 2, fold: 4, epoch: 17, train_loss: 0.016239079565781613, valid_loss: 0.017411355913749763, elapse: 4.74 sec
# seed: 2, fold: 4, epoch: 18, train_loss: 0.015991935007058193, valid_loss: 0.017470685738537994, elapse: 4.84 sec
# seed: 2, fold: 4, epoch: 19, train_loss: 0.015770940427276968, valid_loss: 0.01728454575474773, elapse: 4.53 sec
# seed: 2, fold: 4, epoch: 20, train_loss: 0.01542023069265744, valid_loss: 0.01731096607233797, elapse: 4.46 sec
# seed: 2, fold: 4, epoch: 21, train_loss: 0.015172799441801466, valid_loss: 0.017215966992080212, elapse: 4.85 sec
# seed: 2, fold: 4, epoch: 22, train_loss: 0.014853421510939581, valid_loss: 0.01719727532139846, elapse: 4.77 sec
# seed: 2, fold: 4, epoch: 23, train_loss: 0.014624121065750935, valid_loss: 0.01718279588967562, elapse: 4.71 sec
# seed: 2, fold: 4, epoch: 24, train_loss: 0.014576703060310389, valid_loss: 0.017174612038901874, elapse: 4.83 sec
# seed: 3, fold: 0, epoch: 0, train_loss: 0.4812383666715544, valid_loss: 0.02458972324218069, elapse: 4.63 sec
# seed: 3, fold: 0, epoch: 1, train_loss: 0.020849126688056233, valid_loss: 0.01970990135201386, elapse: 4.83 sec
# seed: 3, fold: 0, epoch: 2, train_loss: 0.018677164989429108, valid_loss: 0.018365948594042232, elapse: 4.78 sec
# seed: 3, fold: 0, epoch: 3, train_loss: 0.017601077093918255, valid_loss: 0.017716823864196027, elapse: 4.82 sec
# seed: 3, fold: 0, epoch: 4, train_loss: 0.017079635530008352, valid_loss: 0.017838340438902377, elapse: 3.83 sec
# seed: 3, fold: 0, epoch: 5, train_loss: 0.016994199897770002, valid_loss: 0.017748526776475565, elapse: 4.50 sec
# seed: 3, fold: 0, epoch: 6, train_loss: 0.01712243969592711, valid_loss: 0.017701464332640172, elapse: 4.86 sec
# seed: 3, fold: 0, epoch: 7, train_loss: 0.01716617430033891, valid_loss: 0.01804898961314133, elapse: 4.51 sec
# seed: 3, fold: 0, epoch: 8, train_loss: 0.01719605372003887, valid_loss: 0.01787939595856837, elapse: 4.58 sec
# seed: 3, fold: 0, epoch: 9, train_loss: 0.017171644558455202, valid_loss: 0.017852486723235677, elapse: 4.16 sec
# seed: 3, fold: 0, epoch: 10, train_loss: 0.017105601485008778, valid_loss: 0.017658457159996033, elapse: 4.83 sec
# seed: 3, fold: 0, epoch: 11, train_loss: 0.017079596751895937, valid_loss: 0.01758136743945735, elapse: 4.78 sec
# seed: 3, fold: 0, epoch: 12, train_loss: 0.017122577889350014, valid_loss: 0.01757954353732722, elapse: 4.25 sec
# seed: 3, fold: 0, epoch: 13, train_loss: 0.016978505350973293, valid_loss: 0.017679446563124656, elapse: 4.78 sec
# seed: 3, fold: 0, epoch: 14, train_loss: 0.01682617046289902, valid_loss: 0.017414740180330616, elapse: 4.70 sec
# seed: 3, fold: 0, epoch: 15, train_loss: 0.016727756567137396, valid_loss: 0.01735548126910414, elapse: 4.69 sec
# seed: 3, fold: 0, epoch: 16, train_loss: 0.0165410579951561, valid_loss: 0.017300762688474997, elapse: 4.74 sec
# seed: 3, fold: 0, epoch: 17, train_loss: 0.01630224763294277, valid_loss: 0.017320053997848715, elapse: 4.77 sec
# seed: 3, fold: 0, epoch: 18, train_loss: 0.016008339768302612, valid_loss: 0.017253048984067782, elapse: 4.80 sec
# seed: 3, fold: 0, epoch: 19, train_loss: 0.015787559561431408, valid_loss: 0.017102813268346447, elapse: 4.85 sec
# seed: 3, fold: 0, epoch: 20, train_loss: 0.015410760552554892, valid_loss: 0.017153263251696315, elapse: 4.87 sec
# seed: 3, fold: 0, epoch: 21, train_loss: 0.01511202283554535, valid_loss: 0.01702259922666209, elapse: 4.82 sec
# seed: 3, fold: 0, epoch: 22, train_loss: 0.014818270306062439, valid_loss: 0.017029288916715554, elapse: 4.70 sec
# seed: 3, fold: 0, epoch: 23, train_loss: 0.01459552481284608, valid_loss: 0.017055434015180383, elapse: 4.81 sec
# seed: 3, fold: 1, epoch: 0, train_loss: 0.48056409401941474, valid_loss: 0.02432109106864248, elapse: 4.51 sec
# seed: 3, fold: 1, epoch: 1, train_loss: 0.020746851217572707, valid_loss: 0.019145973026752472, elapse: 4.81 sec
# seed: 3, fold: 1, epoch: 2, train_loss: 0.018513243353116687, valid_loss: 0.018221456184983255, elapse: 4.73 sec
# seed: 3, fold: 1, epoch: 3, train_loss: 0.01743546727854405, valid_loss: 0.01793230404811246, elapse: 4.74 sec
# seed: 3, fold: 1, epoch: 4, train_loss: 0.01698481148095244, valid_loss: 0.017882738581725528, elapse: 4.80 sec
# seed: 3, fold: 1, epoch: 5, train_loss: 0.016959746375027365, valid_loss: 0.01795775605631726, elapse: 4.67 sec
# seed: 3, fold: 1, epoch: 6, train_loss: 0.017042283295062337, valid_loss: 0.01786530087036746, elapse: 4.84 sec
# seed: 3, fold: 1, epoch: 7, train_loss: 0.017094852171675133, valid_loss: 0.017923292863581863, elapse: 4.93 sec
# seed: 3, fold: 1, epoch: 8, train_loss: 0.01711092586799042, valid_loss: 0.018154186409498965, elapse: 4.75 sec
# seed: 3, fold: 1, epoch: 9, train_loss: 0.01714362191158707, valid_loss: 0.017736182202185903, elapse: 4.80 sec
# seed: 3, fold: 1, epoch: 10, train_loss: 0.0171299275609046, valid_loss: 0.017759552119033677, elapse: 4.84 sec
# seed: 3, fold: 1, epoch: 11, train_loss: 0.017052765588962685, valid_loss: 0.01787436343729496, elapse: 4.69 sec
# seed: 3, fold: 1, epoch: 12, train_loss: 0.016981772446229945, valid_loss: 0.017743684511099544, elapse: 4.80 sec
# seed: 3, fold: 1, epoch: 13, train_loss: 0.016900908324296457, valid_loss: 0.01770133586334331, elapse: 4.89 sec
# seed: 3, fold: 1, epoch: 14, train_loss: 0.016847489911546238, valid_loss: 0.017840074987283776, elapse: 4.75 sec
# seed: 3, fold: 1, epoch: 15, train_loss: 0.016641522077911527, valid_loss: 0.017593765790973392, elapse: 4.75 sec
# seed: 3, fold: 1, epoch: 16, train_loss: 0.016495619547029917, valid_loss: 0.01768179243164403, elapse: 4.82 sec
# seed: 3, fold: 1, epoch: 17, train_loss: 0.01632038786681029, valid_loss: 0.017481445068759576, elapse: 4.82 sec
# seed: 3, fold: 1, epoch: 18, train_loss: 0.016051011880601408, valid_loss: 0.017389296048453875, elapse: 4.77 sec
# seed: 3, fold: 1, epoch: 19, train_loss: 0.015795625311179753, valid_loss: 0.017470267707748073, elapse: 4.87 sec
# seed: 3, fold: 1, epoch: 20, train_loss: 0.015456742872178119, valid_loss: 0.017312667119715894, elapse: 4.79 sec
# seed: 3, fold: 1, epoch: 21, train_loss: 0.015141213924562844, valid_loss: 0.017265555981014456, elapse: 4.50 sec
# seed: 3, fold: 1, epoch: 22, train_loss: 0.014870616423822668, valid_loss: 0.01725535701428141, elapse: 4.77 sec
# seed: 3, fold: 1, epoch: 23, train_loss: 0.01460376160939897, valid_loss: 0.01724697213087763, elapse: 4.72 sec
# seed: 3, fold: 1, epoch: 24, train_loss: 0.014521279984092625, valid_loss: 0.01726244001516274, elapse: 4.60 sec
# seed: 3, fold: 2, epoch: 0, train_loss: 0.4805892460939029, valid_loss: 0.024483842083386012, elapse: 4.79 sec
# seed: 3, fold: 2, epoch: 1, train_loss: 0.020585234047494072, valid_loss: 0.01897330667291369, elapse: 4.83 sec
# seed: 3, fold: 2, epoch: 2, train_loss: 0.01834678722113587, valid_loss: 0.01818614373249667, elapse: 4.82 sec
# seed: 3, fold: 2, epoch: 3, train_loss: 0.017595310061090233, valid_loss: 0.017986479641071387, elapse: 4.79 sec
# seed: 3, fold: 2, epoch: 4, train_loss: 0.01696759743777954, valid_loss: 0.01787426612739052, elapse: 4.84 sec
# seed: 3, fold: 2, epoch: 5, train_loss: 0.016936924382774294, valid_loss: 0.017946183229131357, elapse: 4.39 sec
# seed: 3, fold: 2, epoch: 6, train_loss: 0.017031903020983587, valid_loss: 0.01781270339020661, elapse: 4.35 sec
# seed: 3, fold: 2, epoch: 7, train_loss: 0.01708885362587761, valid_loss: 0.017679239729685443, elapse: 4.74 sec
# seed: 3, fold: 2, epoch: 8, train_loss: 0.0171936538974768, valid_loss: 0.01775280311703682, elapse: 4.82 sec
# seed: 3, fold: 2, epoch: 9, train_loss: 0.017127132360432028, valid_loss: 0.018192882649600506, elapse: 4.73 sec
# seed: 3, fold: 2, epoch: 10, train_loss: 0.017130179701885885, valid_loss: 0.01791822218469211, elapse: 4.49 sec
# seed: 3, fold: 2, epoch: 11, train_loss: 0.01705461457722645, valid_loss: 0.017833831294306688, elapse: 4.80 sec
# seed: 3, fold: 2, epoch: 12, train_loss: 0.016989995799688757, valid_loss: 0.017765838652849197, elapse: 4.91 sec
# seed: 3, fold: 2, epoch: 13, train_loss: 0.016942655316729477, valid_loss: 0.01757199229406459, elapse: 4.60 sec
# seed: 3, fold: 2, epoch: 14, train_loss: 0.016836414545558502, valid_loss: 0.01758220065385103, elapse: 4.39 sec
# seed: 3, fold: 2, epoch: 15, train_loss: 0.016678669624894425, valid_loss: 0.017413350859923023, elapse: 4.80 sec
# seed: 3, fold: 2, epoch: 16, train_loss: 0.016446765890156013, valid_loss: 0.017452843593699592, elapse: 4.83 sec
# seed: 3, fold: 2, epoch: 17, train_loss: 0.016323884341703808, valid_loss: 0.017387359961867334, elapse: 4.82 sec
# seed: 3, fold: 2, epoch: 18, train_loss: 0.01603422271411704, valid_loss: 0.017329231516591142, elapse: 4.84 sec
# seed: 3, fold: 2, epoch: 19, train_loss: 0.01581207711411559, valid_loss: 0.01725750302097627, elapse: 4.94 sec
# seed: 3, fold: 2, epoch: 20, train_loss: 0.015511204718031746, valid_loss: 0.01722971610724926, elapse: 4.82 sec
# seed: 3, fold: 2, epoch: 21, train_loss: 0.015180035150083511, valid_loss: 0.01723414779241596, elapse: 4.86 sec
# ...
# seed: 3, fold: 4, epoch: 6, train_loss: 0.01701507614115658, valid_loss: 0.01794789209961891, elapse: 4.57 sec
# seed: 3, fold: 4, epoch: 7, train_loss: 0.017098397623909557, valid_loss: 0.01807796571935926, elapse: 4.80 sec
# seed: 3, fold: 4, epoch: 8, train_loss: 0.017134922570076542, valid_loss: 0.01823391148022243, elapse: 4.75 sec
# seed: 3, fold: 4, epoch: 9, train_loss: 0.017114573765708053, valid_loss: 0.01822327561676502, elapse: 4.84 sec
# seed: 3, fold: 4, epoch: 10, train_loss: 0.017122146747736395, valid_loss: 0.018113113061657974, elapse: 4.79 sec
# seed: 3, fold: 4, epoch: 11, train_loss: 0.017119135559145092, valid_loss: 0.01779798668410097, elapse: 4.72 sec
# seed: 3, fold: 4, epoch: 12, train_loss: 0.016975409924929987, valid_loss: 0.017853764684072564, elapse: 4.89 sec
# seed: 3, fold: 4, epoch: 13, train_loss: 0.016878762424154127, valid_loss: 0.017744494069899832, elapse: 4.82 sec
# seed: 3, fold: 4, epoch: 14, train_loss: 0.0168423176392157, valid_loss: 0.017690895018833024, elapse: 4.82 sec
# seed: 3, fold: 4, epoch: 15, train_loss: 0.016642145772019157, valid_loss: 0.017658181328858647, elapse: 4.77 sec
# seed: 3, fold: 4, epoch: 16, train_loss: 0.01651285158848201, valid_loss: 0.017647780291736127, elapse: 4.62 sec
# seed: 3, fold: 4, epoch: 17, train_loss: 0.016252793803595116, valid_loss: 0.01747726279177836, elapse: 4.67 sec
# seed: 3, fold: 4, epoch: 18, train_loss: 0.016051515140503212, valid_loss: 0.017504988477698394, elapse: 4.88 sec
# seed: 3, fold: 4, epoch: 19, train_loss: 0.015784617358197767, valid_loss: 0.017304832568126066, elapse: 4.81 sec
# seed: 3, fold: 4, epoch: 20, train_loss: 0.015472775298184242, valid_loss: 0.017273623762386187, elapse: 4.84 sec
# seed: 3, fold: 4, epoch: 21, train_loss: 0.015139711852036957, valid_loss: 0.017210068606904574, elapse: 4.76 sec
# seed: 3, fold: 4, epoch: 22, train_loss: nan, valid_loss: nan, elapse: 4.66 sec
# seed: 3, fold: 4, epoch: 23, train_loss: nan, valid_loss: nan, elapse: 4.65 sec
# seed: 3, fold: 4, epoch: 24, train_loss: nan, valid_loss: nan, elapse: 4.91 sec
# seed: 4, fold: 0, epoch: 0, train_loss: 0.48085299662003916, valid_loss: 0.025175959723336357, elapse: 4.31 sec
# seed: 4, fold: 0, epoch: 1, train_loss: 0.02073277823249067, valid_loss: 0.02007689992231982, elapse: 4.76 sec
# seed: 4, fold: 0, epoch: 2, train_loss: 0.018505834765138403, valid_loss: 0.018403039686381815, elapse: 4.69 sec
# seed: 4, fold: 0, epoch: 3, train_loss: 0.017495462414471134, valid_loss: 0.01790195479989052, elapse: 4.62 sec
# seed: 4, fold: 0, epoch: 4, train_loss: 0.017069882240848266, valid_loss: 0.018017351334648473, elapse: 4.80 sec
# seed: 4, fold: 0, epoch: 5, train_loss: 0.017032002719740074, valid_loss: 0.017793810101492065, elapse: 4.90 sec
# seed: 4, fold: 0, epoch: 6, train_loss: 0.01712996281845414, valid_loss: 0.017928036648247922, elapse: 4.76 sec
# seed: 4, fold: 0, epoch: 7, train_loss: 0.017257930839137323, valid_loss: 0.018155113394771303, elapse: 4.81 sec
# seed: 4, fold: 0, epoch: 8, train_loss: 0.01719932376906492, valid_loss: 0.01783222843493734, elapse: 4.81 sec
# seed: 4, fold: 0, epoch: 9, train_loss: 0.017168196329873972, valid_loss: 0.017826682728316102, elapse: 4.83 sec
# seed: 4, fold: 0, epoch: 10, train_loss: 0.017215432194264038, valid_loss: 0.017619141483945507, elapse: 4.60 sec
# seed: 4, fold: 0, epoch: 11, train_loss: 0.017231265292165503, valid_loss: 0.017546343883233412, elapse: 4.89 sec
# seed: 4, fold: 0, epoch: 12, train_loss: 0.017054365205484024, valid_loss: 0.017603205570152828, elapse: 4.79 sec
# seed: 4, fold: 0, epoch: 13, train_loss: 0.01695532992185242, valid_loss: 0.01746131769780602, elapse: 4.76 sec
# seed: 4, fold: 0, epoch: 14, train_loss: 0.016895364106133366, valid_loss: 0.0174628810690982, elapse: 4.63 sec
# seed: 4, fold: 0, epoch: 15, train_loss: 0.016708056172490982, valid_loss: 0.017278204006808146, elapse: 4.65 sec
# seed: 4, fold: 0, epoch: 16, train_loss: 0.01653166766534897, valid_loss: 0.01725636992071356, elapse: 4.71 sec
# seed: 4, fold: 0, epoch: 17, train_loss: 0.016310009524982044, valid_loss: 0.017326355246560916, elapse: 4.88 sec
# seed: 4, fold: 0, epoch: 18, train_loss: 0.016157838576675757, valid_loss: 0.017148278493966374, elapse: 4.51 sec
# seed: 4, fold: 0, epoch: 19, train_loss: 0.01586295161531239, valid_loss: 0.01713456463600908, elapse: 4.74 sec
# seed: 4, fold: 0, epoch: 20, train_loss: 0.015514772608066383, valid_loss: 0.017044080048799516, elapse: 4.42 sec
# seed: 4, fold: 0, epoch: 21, train_loss: 0.015258386096768621, valid_loss: 0.016987917625478337, elapse: 4.81 sec
# seed: 4, fold: 0, epoch: 22, train_loss: 0.014906301122644672, valid_loss: 0.017015704619032995, elapse: 4.72 sec
# seed: 4, fold: 0, epoch: 23, train_loss: 0.014707918366606253, valid_loss: 0.01698678790458611, elapse: 4.54 sec
# seed: 4, fold: 0, epoch: 24, train_loss: 0.01459930505792516, valid_loss: 0.017003987223974296, elapse: 4.76 sec
# seed: 4, fold: 1, epoch: 0, train_loss: 0.48123704469388856, valid_loss: 0.02467795110174588, elapse: 4.65 sec
# seed: 4, fold: 1, epoch: 1, train_loss: 0.020822587062733888, valid_loss: 0.019367356970906257, elapse: 4.78 sec
# seed: 4, fold: 1, epoch: 2, train_loss: 0.018463817533839792, valid_loss: 0.018216238117643765, elapse: 4.62 sec
# seed: 4, fold: 1, epoch: 3, train_loss: 0.017373691272180882, valid_loss: 0.01812279698039804, elapse: 4.80 sec
# seed: 4, fold: 1, epoch: 4, train_loss: 0.017006800707130537, valid_loss: 0.017931926170630115, elapse: 4.91 sec
# seed: 4, fold: 1, epoch: 5, train_loss: 0.01703660207780173, valid_loss: 0.017926369979977607, elapse: 4.79 sec
# seed: 4, fold: 1, epoch: 6, train_loss: 0.01704594489513305, valid_loss: 0.017764406757695334, elapse: 4.77 sec
# seed: 4, fold: 1, epoch: 7, train_loss: 0.017159104938652827, valid_loss: 0.017942608068031923, elapse: 4.80 sec
# seed: 4, fold: 1, epoch: 8, train_loss: 0.017156016672995402, valid_loss: 0.017780117424471036, elapse: 4.47 sec
# seed: 4, fold: 1, epoch: 9, train_loss: 0.01719395324832549, valid_loss: 0.017776611553771155, elapse: 4.62 sec
# seed: 4, fold: 1, epoch: 10, train_loss: 0.017137594045187436, valid_loss: 0.01786091388868434, elapse: 4.87 sec
# seed: 4, fold: 1, epoch: 11, train_loss: 0.01706426317402481, valid_loss: 0.017783337458968162, elapse: 4.83 sec
# seed: 4, fold: 1, epoch: 12, train_loss: 0.017055455615648824, valid_loss: 0.017666360416582653, elapse: 4.62 sec
# seed: 4, fold: 1, epoch: 13, train_loss: 0.01689882642405964, valid_loss: 0.017852807976305486, elapse: 4.45 sec
# seed: 4, fold: 1, epoch: 14, train_loss: 0.016799464169209893, valid_loss: 0.01780706675989287, elapse: 4.64 sec
# seed: 4, fold: 1, epoch: 15, train_loss: 0.016618268441979903, valid_loss: 0.017837652005255222, elapse: 4.50 sec
# seed: 4, fold: 1, epoch: 16, train_loss: 0.016499518002145483, valid_loss: 0.01749874513064112, elapse: 4.90 sec
# seed: 4, fold: 1, epoch: 17, train_loss: 0.01633965527897116, valid_loss: 0.01748697728450809, elapse: 4.77 sec
# seed: 4, fold: 1, epoch: 18, train_loss: 0.01602552203719851, valid_loss: 0.017497781664133072, elapse: 4.79 sec
# seed: 4, fold: 1, epoch: 19, train_loss: 0.015751723601163305, valid_loss: 0.017356233751135212, elapse: 4.80 sec
# seed: 4, fold: 1, epoch: 20, train_loss: 0.01548237955184096, valid_loss: 0.017312868977231638, elapse: 4.05 sec
# seed: 4, fold: 1, epoch: 21, train_loss: 0.015144556176162114, valid_loss: 0.017319506273737975, elapse: 4.81 sec
# seed: 4, fold: 2, epoch: 0, train_loss: 0.4797838946021553, valid_loss: 0.024761343960251127, elapse: 4.43 sec
# seed: 4, fold: 2, epoch: 1, train_loss: 0.020650465891737003, valid_loss: 0.018999897528971944, elapse: 4.83 sec
# seed: 4, fold: 2, epoch: 2, train_loss: 0.01841688309998616, valid_loss: 0.018666487240365574, elapse: 4.85 sec
# seed: 4, fold: 2, epoch: 3, train_loss: 0.01751739437273447, valid_loss: 0.017980335652828215, elapse: 4.77 sec
# seed: 4, fold: 2, epoch: 4, train_loss: 0.017000482066709927, valid_loss: 0.017856475657650403, elapse: 4.81 sec
# seed: 4, fold: 2, epoch: 5, train_loss: 0.016983020409563745, valid_loss: 0.017880094583545413, elapse: 4.81 sec
# seed: 4, fold: 2, epoch: 6, train_loss: 0.017060393885965797, valid_loss: 0.01784102214234216, elapse: 4.91 sec
# seed: 4, fold: 2, epoch: 7, train_loss: 0.0171265650972508, valid_loss: 0.017894118731575353, elapse: 4.80 sec
# seed: 4, fold: 2, epoch: 8, train_loss: 0.01718343560165469, valid_loss: 0.017770865320094992, elapse: 4.64 sec
# seed: 4, fold: 2, epoch: 9, train_loss: 0.017164388226102226, valid_loss: 0.017871065198310783, elapse: 4.48 sec
# seed: 4, fold: 2, epoch: 10, train_loss: 0.01716733339202145, valid_loss: 0.017615304195455143, elapse: 4.63 sec
# seed: 4, fold: 2, epoch: 11, train_loss: 0.017020333092659712, valid_loss: 0.017820288773093905, elapse: 4.78 sec
# seed: 4, fold: 2, epoch: 12, train_loss: 0.01697550747759532, valid_loss: 0.01775087554539953, elapse: 4.90 sec
# seed: 4, fold: 2, epoch: 13, train_loss: 0.016911628244417734, valid_loss: 0.01758601830473968, elapse: 4.73 sec
# seed: 4, fold: 2, epoch: 14, train_loss: 0.01675325410062636, valid_loss: 0.01747449508735112, elapse: 4.81 sec
# seed: 4, fold: 2, epoch: 15, train_loss: 0.01664809703125038, valid_loss: 0.017491507290729454, elapse: 4.85 sec
# seed: 4, fold: 2, epoch: 16, train_loss: 0.01651943350156796, valid_loss: 0.017364128971738474, elapse: 4.83 sec
# seed: 4, fold: 2, epoch: 17, train_loss: 0.016310526172805956, valid_loss: 0.01730011206652437, elapse: 4.71 sec
# seed: 4, fold: 2, epoch: 18, train_loss: 0.016078432893677466, valid_loss: 0.01737894607441766, elapse: 4.88 sec
# seed: 4, fold: 2, epoch: 19, train_loss: 0.01572303748622105, valid_loss: 0.017386094613799027, elapse: 4.76 sec
# seed: 4, fold: 2, epoch: 20, train_loss: 0.015460441806826038, valid_loss: 0.017244483716785906, elapse: 4.43 sec
# seed: 4, fold: 2, epoch: 21, train_loss: 0.015169097508803226, valid_loss: 0.017176297014313086, elapse: 4.83 sec
# seed: 4, fold: 2, epoch: 22, train_loss: 0.014888596201342518, valid_loss: 0.01725166416061776, elapse: 4.75 sec
# seed: 4, fold: 2, epoch: 23, train_loss: 0.014622881083978691, valid_loss: 0.017172052977340563, elapse: 4.73 sec
# seed: 4, fold: 2, epoch: 24, train_loss: 0.014543545709086069, valid_loss: 0.017153936118951867, elapse: 4.86 sec
# seed: 4, fold: 3, epoch: 0, train_loss: 0.48024347007436596, valid_loss: 0.026866632167782102, elapse: 4.65 sec
# seed: 4, fold: 3, epoch: 1, train_loss: 0.020960829294948042, valid_loss: 0.019003816800458092, elapse: 4.86 sec
# seed: 4, fold: 3, epoch: 2, train_loss: 0.018501018761130777, valid_loss: 0.018093535570161683, elapse: 4.75 sec
# seed: 4, fold: 3, epoch: 3, train_loss: 0.01757436989388172, valid_loss: 0.017982484719582966, elapse: 4.84 sec
# seed: 4, fold: 3, epoch: 4, train_loss: 0.01723534352672489, valid_loss: 0.017715295244540488, elapse: 4.62 sec
# seed: 4, fold: 3, epoch: 5, train_loss: 0.01709076121746414, valid_loss: 0.0177087575463312, elapse: 4.86 sec
# seed: 4, fold: 3, epoch: 6, train_loss: 0.017190077645785135, valid_loss: 0.017927163732903345, elapse: 4.80 sec
# seed: 4, fold: 3, epoch: 7, train_loss: 0.017258131998064724, valid_loss: 0.01771642914307969, elapse: 4.83 sec
# seed: 4, fold: 3, epoch: 8, train_loss: 0.017262776679210903, valid_loss: 0.01787680084151881, elapse: 4.79 sec
# seed: 4, fold: 3, epoch: 9, train_loss: 0.017254960446524015, valid_loss: 0.017709140719047615, elapse: 4.82 sec
# seed: 4, fold: 3, epoch: 10, train_loss: 0.0173566246378249, valid_loss: 0.017756571168346065, elapse: 4.80 sec
# seed: 4, fold: 3, epoch: 11, train_loss: 0.01719827580171219, valid_loss: 0.01767971505011831, elapse: 4.93 sec
# seed: 4, fold: 3, epoch: 12, train_loss: 0.017080301034223776, valid_loss: 0.017576807524476733, elapse: 4.78 sec
# seed: 4, fold: 3, epoch: 13, train_loss: 0.017070859198229038, valid_loss: 0.017850374350590364, elapse: 4.78 sec
# seed: 4, fold: 3, epoch: 14, train_loss: 0.01700501937581145, valid_loss: 0.017496695050171443, elapse: 4.81 sec
# seed: 4, fold: 3, epoch: 15, train_loss: 0.016745647017344618, valid_loss: 0.017393672705761025, elapse: 4.21 sec
# seed: 4, fold: 3, epoch: 16, train_loss: 0.01655880287559568, valid_loss: 0.017215073481202124, elapse: 4.82 sec
# seed: 4, fold: 3, epoch: 17, train_loss: 0.0163791844945239, valid_loss: 0.01722078341990709, elapse: 4.92 sec
# seed: 4, fold: 3, epoch: 18, train_loss: 0.016172594019630247, valid_loss: 0.017136330077690737, elapse: 4.56 sec
# seed: 4, fold: 3, epoch: 19, train_loss: 0.015870279160098755, valid_loss: 0.017008798037256512, elapse: 4.67 sec
# seed: 4, fold: 3, epoch: 20, train_loss: 0.01564578342831869, valid_loss: 0.016976568129445826, elapse: 4.79 sec
# seed: 4, fold: 3, epoch: 21, train_loss: 0.015332104260290878, valid_loss: 0.016896614538771764, elapse: 4.88 sec
# seed: 4, fold: 3, epoch: 22, train_loss: 0.015007739630190359, valid_loss: 0.01687375706221376, elapse: 4.82 sec
# seed: 4, fold: 3, epoch: 23, train_loss: 0.014813060919497755, valid_loss: 0.0168557645753026, elapse: 4.82 sec
# seed: 4, fold: 3, epoch: 24, train_loss: 0.014687285151170648, valid_loss: 0.016867010960621494, elapse: 4.93 sec
# seed: 4, fold: 4, epoch: 0, train_loss: 0.48090225448696944, valid_loss: 0.024870041172419276, elapse: 4.38 sec
# seed: 4, fold: 4, epoch: 1, train_loss: 0.020598789083137028, valid_loss: 0.01958112088697297, elapse: 4.13 sec
# seed: 4, fold: 4, epoch: 2, train_loss: 0.0183777862727858, valid_loss: 0.018452179857662745, elapse: 4.75 sec
# seed: 4, fold: 4, epoch: 3, train_loss: 0.017442723931879667, valid_loss: 0.018133845765675817, elapse: 4.63 sec
# seed: 4, fold: 4, epoch: 4, train_loss: 0.016988238940636318, valid_loss: 0.018202333152294158, elapse: 4.33 sec
# seed: 4, fold: 4, epoch: 5, train_loss: 0.016910147616990667, valid_loss: 0.018173137732914516, elapse: 4.79 sec
# seed: 4, fold: 4, epoch: 6, train_loss: 0.01704115224192324, valid_loss: 0.0182005411280053, elapse: 4.72 sec
# seed: 4, fold: 4, epoch: 7, train_loss: 0.017115717996721683, valid_loss: 0.018014498826648507, elapse: 4.72 sec
# seed: 4, fold: 4, epoch: 8, train_loss: 0.017120164940538612, valid_loss: 0.017820852994918823, elapse: 4.83 sec
# seed: 4, fold: 4, epoch: 9, train_loss: 0.017118984124744715, valid_loss: 0.01800608669540712, elapse: 4.84 sec
# seed: 4, fold: 4, epoch: 10, train_loss: 0.017133065290155187, valid_loss: 0.018118686894220967, elapse: 4.73 sec
# seed: 4, fold: 4, epoch: 11, train_loss: 0.017044788327715967, valid_loss: 0.01791105517851455, elapse: 4.39 sec
# seed: 4, fold: 4, epoch: 12, train_loss: 0.016999223998383335, valid_loss: 0.017924402600952558, elapse: 4.80 sec
# seed: 4, fold: 4, epoch: 13, train_loss: 0.01690987155408315, valid_loss: 0.01776682460414512, elapse: 4.79 sec
# seed: 4, fold: 4, epoch: 14, train_loss: 0.01681152836460134, valid_loss: 0.017639500993703094, elapse: 4.79 sec
# seed: 4, fold: 4, epoch: 15, train_loss: 0.01660869566831684, valid_loss: 0.017666681243905, elapse: 4.80 sec
# seed: 4, fold: 4, epoch: 16, train_loss: 0.01647338997302712, valid_loss: 0.01755570053522076, elapse: 4.65 sec
# seed: 4, fold: 4, epoch: 17, train_loss: 0.016299034036911915, valid_loss: 0.017468065076640674, elapse: 4.80 sec
# seed: 4, fold: 4, epoch: 18, train_loss: 0.01601825522231883, valid_loss: 0.017410896133099284, elapse: 4.73 sec
# seed: 4, fold: 4, epoch: 19, train_loss: 0.015827744058670774, valid_loss: 0.017354050731020313, elapse: 4.76 sec
# seed: 4, fold: 4, epoch: 20, train_loss: 0.015485409863185192, valid_loss: 0.01726296560040542, elapse: 4.71 sec
# seed: 4, fold: 4, epoch: 21, train_loss: 0.015184703883647488, valid_loss: 0.017225793349955762, elapse: 4.58 sec
# seed: 4, fold: 4, epoch: 22, train_loss: 0.0148833266634872, valid_loss: 0.017222289953913006, elapse: 4.75 sec
# seed: 4, fold: 4, epoch: 23, train_loss: 0.01470611144559107, valid_loss: 0.017206166844282833, elapse: 4.69 sec
# seed: 4, fold: 4, epoch: 24, train_loss: 0.014596292182155277, valid_loss: 0.017174095367746695, elapse: 4.63 sec
# CPU times: user 47min 54s, sys: 11.9 s, total: 48min 6s
# Wall time: 47min 33s

# %%
# build prediction dataframe
df['train_predict'] = pd.DataFrame(columns=target_cols, index=df['train_features'].index).fillna(0)
df['test_predict'] = pd.DataFrame(columns=target_cols, index=df['test_features'].index).fillna(0)

df['train_predict'][df['train_cp']['cp_type'] == 'trt_cp'] = oof
df['test_predict'][df['test_cp']['cp_type'] == 'trt_cp'] = pred

# %%
# compute cv logloss
from sklearn.metrics import log_loss

logloss = log_loss(df['train_targets_scored'].values.ravel(), df['train_predict'].values.ravel())
print(f"cv log loss: {logloss}")
# Out:
# cv log loss: 0.01567781859401251

# %%
# create submission file
df['test_predict'].to_csv(f"{path_output}/submission.csv", index=True)
df['test_predict'].to_csv(f"{path_output}/{path_output}-submission.csv", index=True)
